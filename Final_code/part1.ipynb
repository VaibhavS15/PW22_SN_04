# %% [markdown]
# # Social Network Analysis(SOTA)
#
# Dhananjaykumar M P PES1UG19CS140
#
# Tejashwini Hosamani PES1UG19CS539
#
# Vaibhav S PES1UG19CS555
#
# Vrunda Patil PES1UG19CS583

# %% [markdown]
#  # Installed and imported required libraries

# %%
pip install igraph
# Out:
# Requirement already satisfied: igraph in c:\users\hp\anaconda3\lib\site-packages (0.9.10)
# Requirement already satisfied: texttable>=1.6.2 in c:\users\hp\anaconda3\lib\site-packages (from igraph) (1.6.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from igraph import * 
g=Graph()

# %% [markdown]
# ## Loading Dataset

# %%
def addVertex(g,name_str):
    try:
        if(name_str not in g.vs['name']):
            print('Inserted node ',name_str)
            g.add_vertex(name=name_str)
        else:
            print ('Node ',name_str,' already present')
            print(g.vs.find(name_str).index)   
    except KeyError:
        g.add_vertex(name=name_str)
    return g

# %%
def load_dataset(fileName,g):
    fileNums=[0]
    for i,eachNum in enumerate(fileNums):
        print(eachNum)
        fileName="Dataset/facebook/edges/"+str(eachNum)+".edges"
        print('fileName=',fileName)
        f=open(fileName)
        line=f.readline()
        while(line!=''):
            c=(line.split())
            g=addVertex(g,c[0])
            g=addVertex(g,c[1])
            print('Adding ',c[0],'-->',c[1])
            g.add_edge(c[0],c[1]) 
            line=f.readline()
    g.simplify()    
    return

# %%
load_dataset('ABC',g)
print(len(g.vs))
# Out:
# 0
# fileName= Dataset/facebook/edges/0.edges
# Inserted node  186
# Adding  236 --> 186
# Inserted node  122
# Inserted node  285
# Adding  122 --> 285
# Inserted node  24
# Inserted node  346
# Adding  24 --> 346
# Inserted node  271
# Inserted node  304
# Adding  271 --> 304
# Inserted node  176
# Inserted node  9
# Adding  176 --> 9
# Inserted node  130
# Inserted node  329
# Adding  130 --> 329
# Inserted node  204
# Inserted node  213
# Adding  204 --> 213
# Inserted node  252
# Inserted node  332
# Adding  252 --> 332
# Inserted node  82
# Inserted node  65
# Adding  82 --> 65
# Inserted node  276
# Inserted node  26
# Adding  276 --> 26
# Inserted node  280
# Inserted node  272
# Adding  280 --> 272
# Inserted node  211
# Inserted node  199
# Adding  211 --> 199
# Inserted node  84
# Node  236  already present
# 0
# Adding  84 --> 236
# Inserted node  133
# Inserted node  62
# Adding  133 --> 62
# Inserted node  239
# Inserted node  172
# Adding  239 --> 172
# Inserted node  322
# Inserted node  53
# Adding  322 --> 53
# Inserted node  3
# Inserted node  170
# Adding  3 --> 170
# Inserted node  175
# Inserted node  46
# Adding  175 --> 46
# Node  170  already present
# 32
# Node  176  already present
# 8
# Adding  170 --> 176
# Node  170  already present
# 32
# Inserted node  56
# Adding  170 --> 56
# Inserted node  254
# Inserted node  194
# Adding  254 --> 194
# Inserted node  231
# Inserted node  117
# Adding  231 --> 117
# Inserted node  127
# Inserted node  135
# Adding  127 --> 135
# Node  285  already present
# 3
# Inserted node  103
# Adding  285 --> 103
# Inserted node  188
# Node  133  already present
# 25
# Adding  188 --> 133
# Inserted node  23
# Inserted node  116
# Adding  23 --> 116
# Inserted node  73
# Inserted node  299
# Adding  73 --> 299
# Inserted node  288
# Inserted node  315
# Adding  288 --> 315
# Inserted node  119
# Inserted node  323
# Adding  119 --> 323
# Inserted node  48
# Inserted node  57
# Adding  48 --> 57
# Inserted node  200
# Inserted node  98
# Adding  200 --> 98
# Inserted node  313
# Inserted node  63
# Adding  313 --> 63
# Node  199  already present
# 23
# Node  304  already present
# 7
# Adding  199 --> 304
# Node  53  already present
# 30
# Node  346  already present
# 5
# Adding  53 --> 346
# Inserted node  344
# Node  239  already present
# 27
# Adding  344 --> 239
# Node  56  already present
# 35
# Inserted node  67
# Adding  56 --> 67
# Inserted node  118
# Inserted node  325
# Adding  118 --> 325
# Node  188  already present
# 43
# Node  119  already present
# 50
# Adding  188 --> 119
# Node  26  already present
# 19
# Inserted node  277
# Adding  26 --> 277
# Inserted node  134
# Node  56  already present
# 35
# Adding  134 --> 56
# Inserted node  270
# Inserted node  76
# Adding  270 --> 76
# Node  135  already present
# 41
# Inserted node  36
# Adding  135 --> 36
# Inserted node  223
# Node  170  already present
# 32
# Adding  223 --> 170
# Node  170  already present
# 32
# Inserted node  274
# Adding  170 --> 274
# Inserted node  88
# Inserted node  21
# Adding  88 --> 21
# Inserted node  339
# Node  119  already present
# 50
# Adding  339 --> 119
# Inserted node  108
# Inserted node  197
# Adding  108 --> 197
# Inserted node  169
# Node  271  already present
# 6
# Adding  169 --> 271
# Node  62  already present
# 26
# Node  236  already present
# 0
# Adding  62 --> 236
# Inserted node  275
# Inserted node  273
# Adding  275 --> 273
# Node  88  already present
# 69
# Node  186  already present
# 1
# Adding  88 --> 186
# Node  213  already present
# 13
# Node  186  already present
# 1
# Adding  213 --> 186
# Inserted node  83
# Node  23  already present
# 44
# Adding  83 --> 23
# Inserted node  28
# Inserted node  312
# Adding  28 --> 312
# Inserted node  242
# Node  57  already present
# 53
# Adding  242 --> 57
# Inserted node  214
# Inserted node  20
# Adding  214 --> 20
# Inserted node  307
# Inserted node  71
# Adding  307 --> 71
# Node  20  already present
# 82
# Inserted node  333
# Adding  20 --> 333
# Inserted node  207
# Node  322  already present
# 29
# Adding  207 --> 322
# Node  339  already present
# 71
# Inserted node  168
# Adding  339 --> 168
# Inserted node  308
# Node  277  already present
# 62
# Adding  308 --> 277
# Node  186  already present
# 1
# Inserted node  341
# Adding  186 --> 341
# Node  322  already present
# 29
# Node  122  already present
# 2
# Adding  322 --> 122
# Inserted node  128
# Node  9  already present
# 9
# Adding  128 --> 9
# Inserted node  334
# Node  252  already present
# 14
# Adding  334 --> 252
# Inserted node  238
# Inserted node  265
# Adding  238 --> 265
# Node  67  already present
# 59
# Inserted node  141
# Adding  67 --> 141
# Inserted node  78
# Node  273  already present
# 76
# Adding  78 --> 273
# Inserted node  345
# Node  122  already present
# 2
# Adding  345 --> 122
# Node  315  already present
# 49
# Node  345  already present
# 96
# Adding  315 --> 345
# Inserted node  317
# Inserted node  158
# Adding  317 --> 158
# Node  98  already present
# 55
# Node  21  already present
# 70
# Adding  98 --> 21
# Node  339  already present
# 71
# Inserted node  38
# Adding  339 --> 38
# Node  24  already present
# 4
# Inserted node  302
# Adding  24 --> 302
# Inserted node  27
# Inserted node  54
# Adding  27 --> 54
# Node  197  already present
# 73
# Inserted node  139
# Adding  197 --> 139
# Inserted node  109
# Node  118  already present
# 60
# Adding  109 --> 118
# Node  252  already present
# 14
# Inserted node  291
# Adding  252 --> 291
# Node  170  already present
# 32
# Inserted node  142
# Adding  170 --> 142
# Node  82  already present
# 16
# Node  271  already present
# 6
# Adding  82 --> 271
# Inserted node  203
# Node  332  already present
# 15
# Adding  203 --> 332
# Inserted node  105
# Node  9  already present
# 9
# Adding  105 --> 9
# Inserted node  232
# Node  285  already present
# 3
# Adding  232 --> 285
# Inserted node  64
# Inserted node  217
# Adding  64 --> 217
# Node  239  already present
# 27
# Node  62  already present
# 26
# Adding  239 --> 62
# Inserted node  248
# Node  332  already present
# 15
# Adding  248 --> 332
# Node  73  already present
# 46
# Inserted node  126
# Adding  73 --> 126
# Inserted node  224
# Inserted node  261
# Adding  224 --> 261
# Inserted node  283
# Node  3  already present
# 31
# Adding  283 --> 3
# Inserted node  144
# Inserted node  226
# Adding  144 --> 226
# Node  119  already present
# 50
# Node  48  already present
# 52
# Adding  119 --> 48
# Inserted node  290
# Inserted node  25
# Adding  290 --> 25
# Node  172  already present
# 28
# Inserted node  342
# Adding  172 --> 342
# Node  119  already present
# 50
# Node  170  already present
# 32
# Adding  119 --> 170
# Node  285  already present
# 3
# Inserted node  146
# Adding  285 --> 146
# Inserted node  300
# Inserted node  94
# Adding  300 --> 94
# Node  236  already present
# 0
# Node  142  already present
# 106
# Adding  236 --> 142
# Node  346  already present
# 5
# Inserted node  1
# Adding  346 --> 1
# Inserted node  184
# Inserted node  159
# Adding  184 --> 159
# Node  159  already present
# 127
# Node  139  already present
# 103
# Adding  159 --> 139
# Node  53  already present
# 30
# Node  299  already present
# 47
# Adding  53 --> 299
# Inserted node  149
# Node  20  already present
# 82
# Adding  149 --> 20
# Node  83  already present
# 77
# Node  25  already present
# 120
# Adding  83 --> 25
# Node  332  already present
# 15
# Inserted node  13
# Adding  332 --> 13
# Node  25  already present
# 120
# Node  94  already present
# 124
# Adding  25 --> 94
# Node  342  already present
# 121
# Inserted node  59
# Adding  342 --> 59
# Node  238  already present
# 92
# Node  239  already present
# 27
# Adding  238 --> 239
# Inserted node  17
# Inserted node  326
# Adding  17 --> 326
# Inserted node  80
# Inserted node  187
# Adding  80 --> 187
# Node  325  already present
# 61
# Node  109  already present
# 104
# Adding  325 --> 109
# Node  224  already present
# 114
# Node  84  already present
# 24
# Adding  224 --> 84
# Inserted node  161
# Node  142  already present
# 106
# Adding  161 --> 142
# Node  122  already present
# 2
# Node  323  already present
# 51
# Adding  122 --> 323
# Node  161  already present
# 135
# Node  308  already present
# 88
# Adding  161 --> 308
# Node  142  already present
# 106
# Inserted node  66
# Adding  142 --> 66
# Node  308  already present
# 88
# Inserted node  31
# Adding  308 --> 31
# Inserted node  136
# Inserted node  7
# Adding  136 --> 7
# Node  271  already present
# 6
# Node  252  already present
# 14
# Adding  271 --> 252
# Inserted node  255
# Inserted node  49
# Adding  255 --> 49
# Node  48  already present
# 52
# Inserted node  320
# Adding  48 --> 320
# Node  3  already present
# 31
# Inserted node  85
# Adding  3 --> 85
# Inserted node  246
# Node  7  already present
# 139
# Adding  246 --> 7
# Node  109  already present
# 104
# Node  56  already present
# 35
# Adding  109 --> 56
# Node  109  already present
# 104
# Node  119  already present
# 50
# Adding  109 --> 119
# Node  239  already present
# 27
# Node  238  already present
# 92
# Adding  239 --> 238
# Node  272  already present
# 21
# Node  186  already present
# 1
# Adding  272 --> 186
# Node  200  already present
# 54
# Inserted node  123
# Adding  200 --> 123
# Node  285  already present
# 3
# Node  246  already present
# 144
# Adding  285 --> 246
# Node  271  already present
# 6
# Node  188  already present
# 43
# Adding  271 --> 188
# Node  31  already present
# 137
# Node  277  already present
# 62
# Adding  31 --> 277
# Node  326  already present
# 132
# Node  17  already present
# 131
# Adding  326 --> 17
# Inserted node  284
# Node  108  already present
# 72
# Adding  284 --> 108
# Inserted node  140
# Inserted node  137
# Adding  140 --> 137
# Node  56  already present
# 35
# Node  26  already present
# 19
# Adding  56 --> 26
# Inserted node  343
# Inserted node  115
# Adding  343 --> 115
# Node  25  already present
# 120
# Node  323  already present
# 51
# Adding  25 --> 323
# Node  345  already present
# 96
# Node  159  already present
# 127
# Adding  345 --> 159
# Inserted node  297
# Node  26  already present
# 19
# Adding  297 --> 26
# Node  343  already present
# 149
# Node  149  already present
# 128
# Adding  343 --> 149
# Node  320  already present
# 142
# Node  48  already present
# 52
# Adding  320 --> 48
# Node  200  already present
# 54
# Node  109  already present
# 104
# Adding  200 --> 109
# Inserted node  185
# Node  271  already present
# 6
# Adding  185 --> 271
# Node  7  already present
# 139
# Node  136  already present
# 138
# Adding  7 --> 136
# Node  326  already present
# 132
# Node  149  already present
# 128
# Adding  326 --> 149
# Inserted node  104
# Node  56  already present
# 35
# Adding  104 --> 56
# Node  339  already present
# 71
# Node  136  already present
# 138
# Adding  339 --> 136
# Node  308  already present
# 88
# Node  142  already present
# 106
# Adding  308 --> 142
# Inserted node  324
# Node  329  already present
# 11
# Adding  324 --> 329
# Node  9  already present
# 9
# Node  252  already present
# 14
# Adding  9 --> 252
# Node  1  already present
# 125
# Node  315  already present
# 49
# Adding  1 --> 315
# Node  21  already present
# 70
# Node  274  already present
# 68
# Adding  21 --> 274
# Node  119  already present
# 50
# Inserted node  171
# Adding  119 --> 171
# Node  345  already present
# 96
# Node  67  already present
# 59
# Adding  345 --> 67
# Node  280  already present
# 20
# Node  1  already present
# 125
# Adding  280 --> 1
# Node  313  already present
# 56
# Node  265  already present
# 93
# Adding  313 --> 265
# Node  277  already present
# 62
# Node  271  already present
# 6
# Adding  277 --> 271
# Node  56  already present
# 35
# Node  88  already present
# 69
# Adding  56 --> 88
# Node  9  already present
# 9
# Node  203  already present
# 107
# Adding  9 --> 203
# Node  85  already present
# 143
# Node  176  already present
# 8
# Adding  85 --> 176
# Inserted node  111
# Node  343  already present
# 149
# Adding  111 --> 343
# Inserted node  14
# Node  20  already present
# 82
# Adding  14 --> 20
# Inserted node  310
# Inserted node  32
# Adding  310 --> 32
# Node  304  already present
# 7
# Inserted node  30
# Adding  304 --> 30
# Node  199  already present
# 23
# Inserted node  222
# Adding  199 --> 222
# Inserted node  92
# Node  346  already present
# 5
# Adding  92 --> 346
# Inserted node  72
# Inserted node  40
# Adding  72 --> 40
# Node  284  already present
# 146
# Node  184  already present
# 126
# Adding  284 --> 184
# Inserted node  125
# Node  136  already present
# 138
# Adding  125 --> 136
# Node  134  already present
# 63
# Node  118  already present
# 60
# Adding  134 --> 118
# Node  9  already present
# 9
# Node  322  already present
# 29
# Adding  9 --> 322
# Node  302  already present
# 100
# Inserted node  266
# Adding  302 --> 266
# Node  332  already present
# 15
# Node  104  already present
# 153
# Adding  332 --> 104
# Node  40  already present
# 164
# Node  199  already present
# 23
# Adding  40 --> 199
# Inserted node  212
# Node  67  already present
# 59
# Adding  212 --> 67
# Node  200  already present
# 54
# Node  277  already present
# 62
# Adding  200 --> 277
# Node  82  already present
# 16
# Node  169  already present
# 74
# Adding  82 --> 169
# Node  270  already present
# 64
# Node  203  already present
# 107
# Adding  270 --> 203
# Node  308  already present
# 88
# Node  172  already present
# 28
# Adding  308 --> 172
# Node  261  already present
# 115
# Node  63  already present
# 57
# Adding  261 --> 63
# Node  146  already present
# 122
# Node  313  already present
# 56
# Adding  146 --> 313
# Node  188  already present
# 43
# Node  285  already present
# 3
# Adding  188 --> 285
# Node  57  already present
# 53
# Node  92  already present
# 162
# Adding  57 --> 92
# Node  168  already present
# 87
# Node  304  already present
# 7
# Adding  168 --> 304
# Node  199  already present
# 23
# Node  265  already present
# 93
# Adding  199 --> 265
# Node  332  already present
# 15
# Node  98  already present
# 55
# Adding  332 --> 98
# Node  169  already present
# 74
# Node  136  already present
# 138
# Adding  169 --> 136
# Node  213  already present
# 13
# Node  57  already present
# 53
# Adding  213 --> 57
# Node  248  already present
# 112
# Node  277  already present
# 62
# Adding  248 --> 277
# Node  98  already present
# 55
# Node  271  already present
# 6
# Adding  98 --> 271
# Node  56  already present
# 35
# Node  141  already present
# 94
# Adding  56 --> 141
# Node  310  already present
# 158
# Node  17  already present
# 131
# Adding  310 --> 17
# Node  199  already present
# 23
# Node  118  already present
# 60
# Adding  199 --> 118
# Node  239  already present
# 27
# Node  141  already present
# 94
# Adding  239 --> 141
# Node  21  already present
# 70
# Node  212  already present
# 167
# Adding  21 --> 212
# Node  176  already present
# 8
# Node  128  already present
# 90
# Adding  176 --> 128
# Node  175  already present
# 33
# Inserted node  278
# Adding  175 --> 278
# Node  203  already present
# 107
# Node  25  already present
# 120
# Adding  203 --> 25
# Node  265  already present
# 93
# Node  40  already present
# 164
# Adding  265 --> 40
# Node  26  already present
# 19
# Node  252  already present
# 14
# Adding  26 --> 252
# Node  339  already present
# 71
# Inserted node  340
# Adding  339 --> 340
# Node  172  already present
# 28
# Node  232  already present
# 109
# Adding  172 --> 232
# Node  31  already present
# 137
# Inserted node  237
# Adding  31 --> 237
# Inserted node  311
# Node  265  already present
# 93
# Adding  311 --> 265
# Inserted node  309
# Node  135  already present
# 41
# Adding  309 --> 135
# Inserted node  330
# Node  80  already present
# 133
# Adding  330 --> 80
# Inserted node  230
# Inserted node  70
# Adding  230 --> 70
# Node  272  already present
# 21
# Node  159  already present
# 127
# Adding  272 --> 159
# Node  21  already present
# 70
# Node  134  already present
# 63
# Adding  21 --> 134
# Node  24  already present
# 4
# Node  53  already present
# 30
# Adding  24 --> 53
# Node  40  already present
# 164
# Node  332  already present
# 15
# Adding  40 --> 332
# Node  261  already present
# 115
# Inserted node  16
# Adding  261 --> 16
# Node  239  already present
# 27
# Node  223  already present
# 67
# Adding  239 --> 223
# Node  304  already present
# 7
# Inserted node  249
# Adding  304 --> 249
# Node  277  already present
# 62
# Inserted node  39
# Adding  277 --> 39
# Node  224  already present
# 114
# Node  141  already present
# 94
# Adding  224 --> 141
# Node  142  already present
# 106
# Node  345  already present
# 96
# Adding  142 --> 345
# Node  72  already present
# 163
# Node  141  already present
# 94
# Adding  72 --> 141
# Node  313  already present
# 56
# Node  21  already present
# 70
# Adding  313 --> 21
# Node  261  already present
# 115
# Node  271  already present
# 6
# Adding  261 --> 271
# Node  276  already present
# 18
# Node  25  already present
# 120
# Adding  276 --> 25
# Node  109  already present
# 104
# Node  200  already present
# 54
# Adding  109 --> 200
# Node  288  already present
# 48
# Node  25  already present
# 120
# Adding  288 --> 25
# Node  329  already present
# 11
# Node  291  already present
# 105
# Adding  329 --> 291
# Node  194  already present
# 37
# Node  242  already present
# 80
# Adding  194 --> 242
# Node  223  already present
# 67
# Node  203  already present
# 107
# Adding  223 --> 203
# Node  290  already present
# 119
# Node  170  already present
# 32
# Adding  290 --> 170
# Node  261  already present
# 115
# Node  325  already present
# 61
# Adding  261 --> 325
# Node  36  already present
# 66
# Inserted node  251
# Adding  36 --> 251
# Node  291  already present
# 105
# Inserted node  10
# Adding  291 --> 10
# Node  342  already present
# 121
# Node  67  already present
# 59
# Adding  342 --> 67
# Node  21  already present
# 70
# Inserted node  55
# Adding  21 --> 55
# Node  108  already present
# 72
# Node  284  already present
# 146
# Adding  108 --> 284
# Node  3  already present
# 31
# Inserted node  228
# Adding  3 --> 228
# Node  168  already present
# 87
# Node  31  already present
# 137
# Adding  168 --> 31
# Node  67  already present
# 59
# Inserted node  69
# Adding  67 --> 69
# Node  323  already present
# 51
# Node  142  already present
# 106
# Adding  323 --> 142
# Node  261  already present
# 115
# Inserted node  113
# Adding  261 --> 113
# Node  55  already present
# 181
# Node  200  already present
# 54
# Adding  55 --> 200
# Node  13  already present
# 129
# Node  277  already present
# 62
# Adding  13 --> 277
# Node  322  already present
# 29
# Node  25  already present
# 120
# Adding  322 --> 25
# Inserted node  258
# Inserted node  257
# Adding  258 --> 257
# Node  285  already present
# 3
# Node  136  already present
# 138
# Adding  285 --> 136
# Node  80  already present
# 133
# Node  320  already present
# 142
# Adding  80 --> 320
# Node  265  already present
# 93
# Node  98  already present
# 55
# Adding  265 --> 98
# Node  252  already present
# 14
# Node  248  already present
# 112
# Adding  252 --> 248
# Node  62  already present
# 26
# Node  200  already present
# 54
# Adding  62 --> 200
# Node  313  already present
# 56
# Node  54  already present
# 102
# Adding  313 --> 54
# Inserted node  196
# Node  249  already present
# 177
# Adding  196 --> 249
# Node  323  already present
# 51
# Node  85  already present
# 143
# Adding  323 --> 85
# Node  82  already present
# 16
# Node  231  already present
# 38
# Adding  82 --> 231
# Node  141  already present
# 94
# Node  224  already present
# 114
# Adding  141 --> 224
# Node  342  already present
# 121
# Node  119  already present
# 50
# Adding  342 --> 119
# Node  304  already present
# 7
# Node  325  already present
# 61
# Adding  304 --> 325
# Node  136  already present
# 138
# Inserted node  156
# Adding  136 --> 156
# Node  325  already present
# 61
# Node  104  already present
# 153
# Adding  325 --> 104
# Node  211  already present
# 22
# Node  325  already present
# 61
# Adding  211 --> 325
# Node  304  already present
# 7
# Node  158  already present
# 98
# Adding  304 --> 158
# Node  254  already present
# 36
# Node  302  already present
# 100
# Adding  254 --> 302
# Node  92  already present
# 162
# Node  242  already present
# 80
# Adding  92 --> 242
# Node  30  already present
# 160
# Inserted node  303
# Adding  30 --> 303
# Node  274  already present
# 68
# Node  188  already present
# 43
# Adding  274 --> 188
# Node  28  already present
# 78
# Node  310  already present
# 158
# Adding  28 --> 310
# Node  271  already present
# 6
# Node  30  already present
# 160
# Adding  271 --> 30
# Inserted node  286
# Inserted node  81
# Adding  286 --> 81
# Node  144  already present
# 117
# Node  326  already present
# 132
# Adding  144 --> 326
# Node  265  already present
# 93
# Node  56  already present
# 35
# Adding  265 --> 56
# Node  249  already present
# 177
# Node  57  already present
# 53
# Adding  249 --> 57
# Node  341  already present
# 89
# Node  186  already present
# 1
# Adding  341 --> 186
# Inserted node  174
# Inserted node  293
# Adding  174 --> 293
# Inserted node  33
# Inserted node  42
# Adding  33 --> 42
# Node  312  already present
# 79
# Node  28  already present
# 78
# Adding  312 --> 28
# Node  199  already present
# 23
# Node  212  already present
# 167
# Adding  199 --> 212
# Node  9  already present
# 9
# Node  323  already present
# 51
# Adding  9 --> 323
# Node  168  already present
# 87
# Inserted node  347
# Adding  168 --> 347
# Node  67  already present
# 59
# Node  142  already present
# 106
# Adding  67 --> 142
# Node  1  already present
# 125
# Node  53  already present
# 30
# Adding  1 --> 53
# Node  115  already present
# 150
# Inserted node  2
# Adding  115 --> 2
# Node  333  already present
# 85
# Node  2  already present
# 197
# Adding  333 --> 2
# Node  332  already present
# 15
# Node  38  already present
# 99
# Adding  332 --> 38
# Node  291  already present
# 105
# Node  280  already present
# 20
# Adding  291 --> 280
# Node  119  already present
# 50
# Node  54  already present
# 102
# Adding  119 --> 54
# Node  271  already present
# 6
# Node  232  already present
# 109
# Adding  271 --> 232
# Node  135  already present
# 41
# Inserted node  281
# Adding  135 --> 281
# Node  258  already present
# 185
# Node  9  already present
# 9
# Adding  258 --> 9
# Node  285  already present
# 3
# Node  200  already present
# 54
# Adding  285 --> 200
# Node  330  already present
# 173
# Node  94  already present
# 124
# Adding  330 --> 94
# Inserted node  263
# Node  175  already present
# 33
# Adding  263 --> 175
# Node  212  already present
# 167
# Node  304  already present
# 7
# Adding  212 --> 304
# Node  238  already present
# 92
# Node  342  already present
# 121
# Adding  238 --> 342
# Node  284  already present
# 146
# Node  159  already present
# 127
# Adding  284 --> 159
# Node  111  already present
# 156
# Inserted node  279
# Adding  111 --> 279
# Node  141  already present
# 94
# Node  172  already present
# 28
# Adding  141 --> 172
# Node  66  already present
# 136
# Node  21  already present
# 70
# Adding  66 --> 21
# Node  313  already present
# 56
# Node  203  already present
# 107
# Adding  313 --> 203
# Node  84  already present
# 24
# Inserted node  51
# Adding  84 --> 51
# Node  139  already present
# 103
# Node  320  already present
# 142
# Adding  139 --> 320
# Node  25  already present
# 120
# Node  186  already present
# 1
# Adding  25 --> 186
# Node  252  already present
# 14
# Inserted node  338
# Adding  252 --> 338
# Node  200  already present
# 54
# Node  188  already present
# 43
# Adding  200 --> 188
# Node  59  already present
# 130
# Node  342  already present
# 121
# Adding  59 --> 342
# Inserted node  162
# Node  149  already present
# 128
# Adding  162 --> 149
# Node  304  already present
# 7
# Node  322  already present
# 29
# Adding  304 --> 322
# Node  185  already present
# 152
# Node  169  already present
# 74
# Adding  185 --> 169
# Node  252  already present
# 14
# Node  236  already present
# 0
# Adding  252 --> 236
# Node  25  already present
# 120
# Node  290  already present
# 119
# Adding  25 --> 290
# Node  56  already present
# 35
# Node  185  already present
# 152
# Adding  56 --> 185
# Node  158  already present
# 98
# Node  40  already present
# 164
# Adding  158 --> 40
# Node  238  already present
# 92
# Node  222  already present
# 161
# Adding  238 --> 222
# Node  56  already present
# 35
# Node  128  already present
# 90
# Adding  56 --> 128
# Node  199  already present
# 23
# Node  261  already present
# 115
# Adding  199 --> 261
# Node  271  already present
# 6
# Node  203  already present
# 107
# Adding  271 --> 203
# Node  63  already present
# 57
# Node  313  already present
# 56
# Adding  63 --> 313
# Node  62  already present
# 26
# Node  161  already present
# 135
# Adding  62 --> 161
# Node  302  already present
# 100
# Node  57  already present
# 53
# Adding  302 --> 57
# Inserted node  19
# Node  175  already present
# 33
# Adding  19 --> 175
# Node  98  already present
# 55
# Node  172  already present
# 28
# Adding  98 --> 172
# Node  28  already present
# 78
# Node  144  already present
# 117
# Adding  28 --> 144
# Node  249  already present
# 177
# Node  213  already present
# 13
# Adding  249 --> 213
# Node  239  already present
# 27
# Node  252  already present
# 14
# Adding  239 --> 252
# Node  332  already present
# 15
# Node  25  already present
# 120
# Adding  332 --> 25
# Node  265  already present
# 93
# Node  203  already present
# 107
# Adding  265 --> 203
# Node  303  already present
# 189
# Node  104  already present
# 153
# Adding  303 --> 104
# Node  339  already present
# 71
# Node  161  already present
# 135
# Adding  339 --> 161
# Node  119  already present
# 50
# Node  39  already present
# 178
# Adding  119 --> 39
# Node  239  already present
# 27
# Node  211  already present
# 22
# Adding  239 --> 211
# Node  313  already present
# 56
# Node  172  already present
# 28
# Adding  313 --> 172
# Node  200  already present
# 54
# Node  122  already present
# 2
# Adding  200 --> 122
# Node  104  already present
# 153
# Node  303  already present
# 189
# Adding  104 --> 303
# Inserted node  75
# Node  9  already present
# 9
# Adding  75 --> 9
# Node  137  already present
# 148
# Node  312  already present
# 79
# Adding  137 --> 312
# Node  272  already present
# 21
# Node  203  already present
# 107
# Adding  272 --> 203
# Inserted node  218
# Node  78  already present
# 95
# Adding  218 --> 78
# Node  261  already present
# 115
# Inserted node  268
# Adding  261 --> 268
# Inserted node  314
# Node  65  already present
# 17
# Adding  314 --> 65
# Node  57  already present
# 53
# Node  213  already present
# 13
# Adding  57 --> 213
# Node  21  already present
# 70
# Node  56  already present
# 35
# Adding  21 --> 56
# Node  7  already present
# 139
# Node  213  already present
# 13
# Adding  7 --> 213
# Node  139  already present
# 103
# Node  281  already present
# 198
# Adding  139 --> 281
# Inserted node  5
# Node  122  already present
# 2
# Adding  5 --> 122
# Node  55  already present
# 181
# Node  21  already present
# 70
# Adding  55 --> 21
# Node  80  already present
# 133
# Node  24  already present
# 4
# Adding  80 --> 24
# Inserted node  178
# Node  38  already present
# 99
# Adding  178 --> 38
# Node  186  already present
# 1
# Node  109  already present
# 104
# Adding  186 --> 109
# Node  304  already present
# 7
# Node  21  already present
# 70
# Adding  304 --> 21
# Inserted node  192
# Node  49  already present
# 141
# Adding  192 --> 49
# Node  203  already present
# 107
# Node  21  already present
# 70
# Adding  203 --> 21
# Node  285  already present
# 3
# Node  271  already present
# 6
# Adding  285 --> 271
# Node  122  already present
# 2
# Node  248  already present
# 112
# Adding  122 --> 248
# Node  104  already present
# 153
# Node  322  already present
# 29
# Adding  104 --> 322
# Node  312  already present
# 79
# Inserted node  243
# Adding  312 --> 243
# Node  302  already present
# 100
# Node  254  already present
# 36
# Adding  302 --> 254
# Node  236  already present
# 0
# Node  169  already present
# 74
# Adding  236 --> 169
# Node  304  already present
# 7
# Node  324  already present
# 154
# Adding  304 --> 324
# Node  266  already present
# 166
# Node  249  already present
# 177
# Adding  266 --> 249
# Node  3  already present
# 31
# Node  280  already present
# 20
# Adding  3 --> 280
# Node  243  already present
# 212
# Node  312  already present
# 79
# Adding  243 --> 312
# Node  211  already present
# 22
# Node  98  already present
# 55
# Adding  211 --> 98
# Inserted node  195
# Inserted node  181
# Adding  195 --> 181
# Inserted node  8
# Inserted node  245
# Adding  8 --> 245
# Node  297  already present
# 151
# Node  185  already present
# 152
# Adding  297 --> 185
# Node  113  already present
# 184
# Node  104  already present
# 153
# Adding  113 --> 104
# Node  10  already present
# 180
# Node  142  already present
# 106
# Adding  10 --> 142
# Inserted node  129
# Node  7  already present
# 139
# Adding  129 --> 7
# Node  56  already present
# 35
# Node  297  already present
# 151
# Adding  56 --> 297
# Node  248  already present
# 112
# Node  323  already present
# 51
# Adding  248 --> 323
# Node  273  already present
# 76
# Inserted node  328
# Adding  273 --> 328
# Node  115  already present
# 150
# Node  19  already present
# 204
# Adding  115 --> 19
# Node  36  already present
# 66
# Node  309  already present
# 172
# Adding  36 --> 309
# Node  129  already present
# 217
# Node  168  already present
# 87
# Adding  129 --> 168
# Node  242  already present
# 80
# Node  194  already present
# 37
# Adding  242 --> 194
# Node  343  already present
# 149
# Node  2  already present
# 197
# Adding  343 --> 2
# Node  21  already present
# 70
# Node  169  already present
# 74
# Adding  21 --> 169
# Node  226  already present
# 118
# Node  343  already present
# 149
# Adding  226 --> 343
# Node  40  already present
# 164
# Node  200  already present
# 54
# Adding  40 --> 200
# Node  172  already present
# 28
# Inserted node  331
# Adding  172 --> 331
# Node  326  already present
# 132
# Node  343  already present
# 149
# Adding  326 --> 343
# Node  134  already present
# 63
# Node  26  already present
# 19
# Adding  134 --> 26
# Node  332  already present
# 15
# Node  329  already present
# 11
# Adding  332 --> 329
# Node  3  already present
# 31
# Node  200  already present
# 54
# Adding  3 --> 200
# Node  331  already present
# 219
# Node  109  already present
# 104
# Adding  331 --> 109
# Inserted node  150
# Node  128  already present
# 90
# Adding  150 --> 128
# Inserted node  101
# Node  299  already present
# 47
# Adding  101 --> 299
# Node  203  already present
# 107
# Node  59  already present
# 130
# Adding  203 --> 59
# Node  231  already present
# 38
# Node  315  already present
# 49
# Adding  231 --> 315
# Node  265  already present
# 93
# Node  199  already present
# 23
# Adding  265 --> 199
# Inserted node  99
# Inserted node  296
# Adding  99 --> 296
# Node  322  already present
# 29
# Node  290  already present
# 119
# Adding  322 --> 290
# Node  296  already present
# 223
# Inserted node  102
# Adding  296 --> 102
# Node  118  already present
# 60
# Node  261  already present
# 115
# Adding  118 --> 261
# Node  238  already present
# 92
# Node  56  already present
# 35
# Adding  238 --> 56
# Node  117  already present
# 39
# Node  231  already present
# 38
# Adding  117 --> 231
# Node  312  already present
# 79
# Node  149  already present
# 128
# Adding  312 --> 149
# Node  304  already present
# 7
# Node  308  already present
# 88
# Adding  304 --> 308
# Node  105  already present
# 108
# Node  277  already present
# 62
# Adding  105 --> 277
# Node  204  already present
# 12
# Node  196  already present
# 187
# Adding  204 --> 196
# Node  315  already present
# 49
# Node  303  already present
# 189
# Adding  315 --> 303
# Node  284  already present
# 146
# Node  21  already present
# 70
# Adding  284 --> 21
# Node  239  already present
# 27
# Node  21  already present
# 70
# Adding  239 --> 21
# Node  312  already present
# 79
# Node  326  already present
# 132
# Adding  312 --> 326
# Node  277  already present
# 62
# Node  161  already present
# 135
# Adding  277 --> 161
# Node  340  already present
# 169
# Node  213  already present
# 13
# Adding  340 --> 213
# Node  98  already present
# 55
# Node  223  already present
# 67
# Adding  98 --> 223
# Node  172  already present
# 28
# Node  277  already present
# 62
# Adding  172 --> 277
# Node  128  already present
# 90
# Node  104  already present
# 153
# Adding  128 --> 104
# Node  313  already present
# 56
# Node  222  already present
# 161
# Adding  313 --> 222
# Node  98  already present
# 55
# Node  331  already present
# 219
# Adding  98 --> 331
# Node  299  already present
# 47
# Node  194  already present
# 37
# Adding  299 --> 194
# Node  122  already present
# 2
# Node  141  already present
# 94
# Adding  122 --> 141
# Node  324  already present
# 154
# Node  217  already present
# 111
# Adding  324 --> 217
# Node  291  already present
# 105
# Node  25  already present
# 120
# Adding  291 --> 25
# Node  13  already present
# 129
# Node  188  already present
# 43
# Adding  13 --> 188
# Node  104  already present
# 153
# Inserted node  318
# Adding  104 --> 318
# Node  261  already present
# 115
# Node  65  already present
# 17
# Adding  261 --> 65
# Node  265  already present
# 93
# Node  128  already present
# 90
# Adding  265 --> 128
# Inserted node  163
# Inserted node  173
# Adding  163 --> 173
# Node  116  already present
# 45
# Node  14  already present
# 157
# Adding  116 --> 14
# Node  92  already present
# 162
# Node  1  already present
# 125
# Adding  92 --> 1
# Node  26  already present
# 19
# Node  3  already present
# 31
# Adding  26 --> 3
# Inserted node  165
# Inserted node  121
# Adding  165 --> 121
# Node  3  already present
# 31
# Node  25  already present
# 120
# Adding  3 --> 25
# Node  149  already present
# 128
# Node  226  already present
# 118
# Adding  149 --> 226
# Node  328  already present
# 218
# Inserted node  306
# Adding  328 --> 306
# Node  172  already present
# 28
# Node  141  already present
# 94
# Adding  172 --> 141
# Node  303  already present
# 189
# Node  315  already present
# 49
# Adding  303 --> 315
# Node  56  already present
# 35
# Node  239  already present
# 27
# Adding  56 --> 239
# Node  122  already present
# 2
# Node  274  already present
# 68
# Adding  122 --> 274
# Node  46  already present
# 34
# Inserted node  177
# Adding  46 --> 177
# Node  249  already present
# 177
# Inserted node  180
# Adding  249 --> 180
# Node  73  already present
# 46
# Node  1  already present
# 125
# Adding  73 --> 1
# Node  272  already present
# 21
# Node  346  already present
# 5
# Adding  272 --> 346
# Node  53  already present
# 30
# Node  48  already present
# 52
# Adding  53 --> 48
# Node  199  already present
# 23
# Node  119  already present
# 50
# Adding  199 --> 119
# Node  248  already present
# 112
# Node  38  already present
# 99
# Adding  248 --> 38
# Node  24  already present
# 4
# Node  187  already present
# 134
# Adding  24 --> 187
# Node  196  already present
# 187
# Node  67  already present
# 59
# Adding  196 --> 67
# Node  304  already present
# 7
# Node  172  already present
# 28
# Adding  304 --> 172
# Inserted node  87
# Node  136  already present
# 138
# Adding  87 --> 136
# Node  323  already present
# 51
# Node  141  already present
# 94
# Adding  323 --> 141
# Node  323  already present
# 51
# Node  62  already present
# 26
# Adding  323 --> 62
# Inserted node  189
# Node  217  already present
# 111
# Adding  189 --> 217
# Node  280  already present
# 20
# Node  236  already present
# 0
# Adding  280 --> 236
# Node  115  already present
# 150
# Node  137  already present
# 148
# Adding  115 --> 137
# Node  25  already present
# 120
# Node  276  already present
# 18
# Adding  25 --> 276
# Node  186  already present
# 1
# Node  55  already present
# 181
# Adding  186 --> 55
# Node  30  already present
# 160
# Node  56  already present
# 35
# Adding  30 --> 56
# Inserted node  60
# Node  285  already present
# 3
# Adding  60 --> 285
# Node  197  already present
# 73
# Node  127  already present
# 40
# Adding  197 --> 127
# Node  334  already present
# 91
# Node  26  already present
# 19
# Adding  334 --> 26
# Node  304  already present
# 7
# Node  170  already present
# 32
# Adding  304 --> 170
# Inserted node  259
# Node  8  already present
# 215
# Adding  259 --> 8
# Node  346  already present
# 5
# Node  184  already present
# 126
# Adding  346 --> 184
# Node  186  already present
# 1
# Node  199  already present
# 23
# Adding  186 --> 199
# Node  200  already present
# 54
# Node  39  already present
# 178
# Adding  200 --> 39
# Node  185  already present
# 152
# Node  344  already present
# 58
# Adding  185 --> 344
# Node  184  already present
# 126
# Node  329  already present
# 11
# Adding  184 --> 329
# Node  149  already present
# 128
# Node  162  already present
# 203
# Adding  149 --> 162
# Node  285  already present
# 3
# Node  213  already present
# 13
# Adding  285 --> 213
# Node  185  already present
# 152
# Node  290  already present
# 119
# Adding  185 --> 290
# Node  13  already present
# 129
# Node  261  already present
# 115
# Adding  13 --> 261
# Node  204  already present
# 12
# Node  5  already present
# 209
# Adding  204 --> 5
# Node  109  already present
# 104
# Node  26  already present
# 19
# Adding  109 --> 26
# Node  169  already present
# 74
# Node  40  already present
# 164
# Adding  169 --> 40
# Node  194  already present
# 37
# Node  196  already present
# 187
# Adding  194 --> 196
# Node  85  already present
# 143
# Node  156  already present
# 188
# Adding  85 --> 156
# Node  67  already present
# 59
# Node  55  already present
# 181
# Adding  67 --> 55
# Node  98  already present
# 55
# Node  285  already present
# 3
# Adding  98 --> 285
# Node  123  already present
# 145
# Node  342  already present
# 121
# Adding  123 --> 342
# Node  118  already present
# 60
# Node  283  already present
# 116
# Adding  118 --> 283
# Inserted node  45
# Node  67  already present
# 59
# Adding  45 --> 67
# Node  80  already present
# 133
# Node  48  already present
# 52
# Adding  80 --> 48
# Node  162  already present
# 203
# Node  343  already present
# 149
# Adding  162 --> 343
# Node  272  already present
# 21
# Node  21  already present
# 70
# Adding  272 --> 21
# Node  271  already present
# 6
# Node  133  already present
# 25
# Adding  271 --> 133
# Node  67  already present
# 59
# Node  297  already present
# 151
# Adding  67 --> 297
# Node  13  already present
# 129
# Node  118  already present
# 60
# Adding  13 --> 118
# Node  115  already present
# 150
# Node  28  already present
# 78
# Adding  115 --> 28
# Node  230  already present
# 174
# Node  23  already present
# 44
# Adding  230 --> 23
# Inserted node  58
# Inserted node  269
# Adding  58 --> 269
# Node  46  already present
# 34
# Node  175  already present
# 33
# Adding  46 --> 175
# Node  25  already present
# 120
# Node  169  already present
# 74
# Adding  25 --> 169
# Node  80  already present
# 133
# Node  57  already present
# 53
# Adding  80 --> 57
# Node  135  already present
# 41
# Node  197  already present
# 73
# Adding  135 --> 197
# Node  203  already present
# 107
# Node  161  already present
# 135
# Adding  203 --> 161
# Node  113  already present
# 184
# Node  261  already present
# 115
# Adding  113 --> 261
# Node  116  already present
# 45
# Node  23  already present
# 44
# Adding  116 --> 23
# Node  275  already present
# 75
# Node  218  already present
# 206
# Adding  275 --> 218
# Node  285  already present
# 3
# Node  170  already present
# 32
# Adding  285 --> 170
# Node  314  already present
# 208
# Node  199  already present
# 23
# Adding  314 --> 199
# Node  279  already present
# 200
# Node  111  already present
# 156
# Adding  279 --> 111
# Node  126  already present
# 113
# Node  48  already present
# 52
# Adding  126 --> 48
# Node  36  already present
# 66
# Node  320  already present
# 142
# Adding  36 --> 320
# Node  137  already present
# 148
# Inserted node  167
# Adding  137 --> 167
# Node  140  already present
# 147
# Node  326  already present
# 132
# Adding  140 --> 326
# Node  130  already present
# 10
# Node  48  already present
# 52
# Adding  130 --> 48
# Node  302  already present
# 100
# Node  94  already present
# 124
# Adding  302 --> 94
# Node  315  already present
# 49
# Node  80  already present
# 133
# Adding  315 --> 80
# Node  101  already present
# 221
# Node  80  already present
# 133
# Adding  101 --> 80
# Node  23  already present
# 44
# Inserted node  227
# Adding  23 --> 227
# Node  92  already present
# 162
# Node  194  already present
# 37
# Adding  92 --> 194
# Node  2  already present
# 197
# Node  20  already present
# 82
# Adding  2 --> 20
# Node  72  already present
# 163
# Node  252  already present
# 14
# Adding  72 --> 252
# Node  323  already present
# 51
# Inserted node  96
# Adding  323 --> 96
# Inserted node  91
# Node  8  already present
# 215
# Adding  91 --> 8
# Inserted node  143
# Node  177  already present
# 231
# Adding  143 --> 177
# Node  200  already present
# 54
# Node  30  already present
# 160
# Adding  200 --> 30
# Node  257  already present
# 186
# Node  26  already present
# 19
# Adding  257 --> 26
# Node  331  already present
# 219
# Node  324  already present
# 154
# Adding  331 --> 324
# Node  142  already present
# 106
# Node  322  already present
# 29
# Adding  142 --> 322
# Node  188  already present
# 43
# Node  104  already present
# 153
# Adding  188 --> 104
# Node  239  already present
# 27
# Node  276  already present
# 18
# Adding  239 --> 276
# Node  23  already present
# 44
# Inserted node  61
# Adding  23 --> 61
# Node  325  already present
# 61
# Node  21  already present
# 70
# Adding  325 --> 21
# Node  204  already present
# 12
# Node  94  already present
# 124
# Adding  204 --> 94
# Node  346  already present
# 5
# Node  194  already present
# 37
# Adding  346 --> 194
# Node  223  already present
# 67
# Node  186  already present
# 1
# Adding  223 --> 186
# Node  56  already present
# 35
# Node  252  already present
# 14
# Adding  56 --> 252
# Node  113  already present
# 184
# Node  142  already present
# 106
# Adding  113 --> 142
# Node  26  already present
# 19
# Node  21  already present
# 70
# Adding  26 --> 21
# Node  285  already present
# 3
# Node  323  already present
# 51
# Adding  285 --> 323
# Node  290  already present
# 119
# Node  176  already present
# 8
# Adding  290 --> 176
# Inserted node  93
# Node  167  already present
# 240
# Adding  93 --> 167
# Node  276  already present
# 18
# Node  122  already present
# 2
# Adding  276 --> 122
# Node  96  already present
# 242
# Node  133  already present
# 25
# Adding  96 --> 133
# Inserted node  41
# Node  243  already present
# 212
# Adding  41 --> 243
# Node  188  already present
# 43
# Node  304  already present
# 7
# Adding  188 --> 304
# Node  203  already present
# 107
# Node  313  already present
# 56
# Adding  203 --> 313
# Node  200  already present
# 54
# Node  170  already present
# 32
# Adding  200 --> 170
# Node  232  already present
# 109
# Node  200  already present
# 54
# Adding  232 --> 200
# Inserted node  235
# Node  5  already present
# 209
# Adding  235 --> 5
# Inserted node  6
# Inserted node  89
# Adding  6 --> 89
# Node  171  already present
# 155
# Inserted node  107
# Adding  171 --> 107
# Node  257  already present
# 186
# Node  169  already present
# 74
# Adding  257 --> 169
# Node  224  already present
# 114
# Node  232  already present
# 109
# Adding  224 --> 232
# Node  271  already present
# 6
# Inserted node  79
# Adding  271 --> 79
# Node  187  already present
# 134
# Node  24  already present
# 4
# Adding  187 --> 24
# Node  141  already present
# 94
# Node  67  already present
# 59
# Adding  141 --> 67
# Node  113  already present
# 184
# Node  66  already present
# 136
# Adding  113 --> 66
# Node  56  already present
# 35
# Node  103  already present
# 42
# Adding  56 --> 103
# Node  59  already present
# 130
# Node  271  already present
# 6
# Adding  59 --> 271
# Node  40  already present
# 164
# Node  213  already present
# 13
# Adding  40 --> 213
# Node  158  already present
# 98
# Node  26  already present
# 19
# Adding  158 --> 26
# Node  211  already present
# 22
# Node  82  already present
# 16
# Adding  211 --> 82
# Node  285  already present
# 3
# Inserted node  208
# Adding  285 --> 208
# Node  119  already present
# 50
# Node  285  already present
# 3
# Adding  119 --> 285
# Node  26  already present
# 19
# Node  9  already present
# 9
# Adding  26 --> 9
# Node  40  already present
# 164
# Node  133  already present
# 25
# Adding  40 --> 133
# Node  143  already present
# 244
# Node  175  already present
# 33
# Adding  143 --> 175
# Node  56  already present
# 35
# Inserted node  132
# Adding  56 --> 132
# Node  45  already present
# 237
# Inserted node  221
# Adding  45 --> 221
# Node  212  already present
# 167
# Node  344  already present
# 58
# Adding  212 --> 344
# Node  285  already present
# 3
# Node  315  already present
# 49
# Adding  285 --> 315
# Inserted node  301
# Node  324  already present
# 154
# Adding  301 --> 324
# Node  21  already present
# 70
# Node  170  already present
# 32
# Adding  21 --> 170
# Node  326  already present
# 132
# Node  214  already present
# 81
# Adding  326 --> 214
# Node  281  already present
# 198
# Node  159  already present
# 127
# Adding  281 --> 159
# Node  281  already present
# 198
# Node  251  already present
# 179
# Adding  281 --> 251
# Node  109  already present
# 104
# Node  67  already present
# 59
# Adding  109 --> 67
# Node  25  already present
# 120
# Node  232  already present
# 109
# Adding  25 --> 232
# Node  59  already present
# 130
# Node  56  already present
# 35
# Adding  59 --> 56
# Node  92  already present
# 162
# Node  180  already present
# 232
# Adding  92 --> 180
# Node  122  already present
# 2
# Node  284  already present
# 146
# Adding  122 --> 284
# Node  322  already present
# 29
# Node  48  already present
# 52
# Adding  322 --> 48
# Node  277  already present
# 62
# Node  308  already present
# 88
# Adding  277 --> 308
# Node  290  already present
# 119
# Node  323  already present
# 51
# Adding  290 --> 323
# Node  167  already present
# 240
# Node  93  already present
# 246
# Adding  167 --> 93
# Inserted node  250
# Node  59  already present
# 130
# Adding  250 --> 59
# Inserted node  106
# Inserted node  29
# Adding  106 --> 29
# Node  274  already present
# 68
# Node  341  already present
# 89
# Adding  274 --> 341
# Node  249  already present
# 177
# Node  302  already present
# 100
# Adding  249 --> 302
# Node  118  already present
# 60
# Node  239  already present
# 27
# Adding  118 --> 239
# Node  111  already present
# 156
# Inserted node  337
# Adding  111 --> 337
# Node  252  already present
# 14
# Node  109  already present
# 104
# Adding  252 --> 109
# Node  56  already present
# 35
# Node  55  already present
# 181
# Adding  56 --> 55
# Node  80  already present
# 133
# Node  266  already present
# 166
# Adding  80 --> 266
# Node  252  already present
# 14
# Node  134  already present
# 63
# Adding  252 --> 134
# Node  104  already present
# 153
# Node  67  already present
# 59
# Adding  104 --> 67
# Node  94  already present
# 124
# Node  346  already present
# 5
# Adding  94 --> 346
# Node  141  already present
# 94
# Node  280  already present
# 20
# Adding  141 --> 280
# Node  325  already present
# 61
# Node  161  already present
# 135
# Adding  325 --> 161
# Node  322  already present
# 29
# Node  203  already present
# 107
# Adding  322 --> 203
# Node  96  already present
# 242
# Node  274  already present
# 68
# Adding  96 --> 274
# Node  158  already present
# 98
# Node  315  already present
# 49
# Adding  158 --> 315
# Node  199  already present
# 23
# Node  98  already present
# 55
# Adding  199 --> 98
# Node  134  already present
# 63
# Node  132  already present
# 254
# Adding  134 --> 132
# Node  280  already present
# 20
# Node  98  already present
# 55
# Adding  280 --> 98
# Node  254  already present
# 36
# Node  187  already present
# 134
# Adding  254 --> 187
# Node  329  already present
# 11
# Node  269  already present
# 239
# Adding  329 --> 269
# Node  297  already present
# 151
# Node  21  already present
# 70
# Adding  297 --> 21
# Inserted node  100
# Node  150  already present
# 220
# Adding  100 --> 150
# Inserted node  110
# Inserted node  264
# Adding  110 --> 264
# Node  266  already present
# 166
# Node  330  already present
# 173
# Adding  266 --> 330
# Node  171  already present
# 155
# Node  150  already present
# 220
# Adding  171 --> 150
# Node  322  already present
# 29
# Node  45  already present
# 237
# Adding  322 --> 45
# Node  72  already present
# 163
# Node  165  already present
# 228
# Adding  72 --> 165
# Node  344  already present
# 58
# Node  257  already present
# 186
# Adding  344 --> 257
# Node  184  already present
# 126
# Node  21  already present
# 70
# Adding  184 --> 21
# Node  119  already present
# 50
# Node  332  already present
# 15
# Adding  119 --> 332
# Node  257  already present
# 186
# Node  236  already present
# 0
# Adding  257 --> 236
# Node  277  already present
# 62
# Node  324  already present
# 154
# Adding  277 --> 324
# Node  332  already present
# 15
# Node  248  already present
# 112
# Adding  332 --> 248
# Node  329  already present
# 11
# Node  119  already present
# 50
# Adding  329 --> 119
# Inserted node  225
# Inserted node  86
# Adding  225 --> 86
# Node  232  already present
# 109
# Node  56  already present
# 35
# Adding  232 --> 56
# Node  291  already present
# 105
# Node  224  already present
# 114
# Adding  291 --> 224
# Node  53  already present
# 30
# Node  196  already present
# 187
# Adding  53 --> 196
# Node  315  already present
# 49
# Node  213  already present
# 13
# Adding  315 --> 213
# Node  322  already present
# 29
# Node  136  already present
# 138
# Adding  322 --> 136
# Node  181  already present
# 214
# Inserted node  152
# Adding  181 --> 152
# Node  141  already present
# 94
# Node  257  already present
# 186
# Adding  141 --> 257
# Node  180  already present
# 232
# Node  80  already present
# 133
# Adding  180 --> 80
# Node  26  already present
# 19
# Node  199  already present
# 23
# Adding  26 --> 199
# Node  45  already present
# 237
# Node  104  already present
# 153
# Adding  45 --> 104
# Node  332  already present
# 15
# Node  67  already present
# 59
# Adding  332 --> 67
# Node  303  already present
# 189
# Node  45  already present
# 237
# Adding  303 --> 45
# Node  250  already present
# 257
# Node  252  already present
# 14
# Adding  250 --> 252
# Node  3  already present
# 31
# Node  26  already present
# 19
# Adding  3 --> 26
# Node  98  already present
# 55
# Inserted node  148
# Adding  98 --> 148
# Node  185  already present
# 152
# Node  55  already present
# 181
# Adding  185 --> 55
# Node  172  already present
# 28
# Node  239  already present
# 27
# Adding  172 --> 239
# Inserted node  295
# Node  239  already present
# 27
# Adding  295 --> 239
# Node  325  already present
# 61
# Node  98  already present
# 55
# Adding  325 --> 98
# Node  252  already present
# 14
# Node  113  already present
# 184
# Adding  252 --> 113
# Node  323  already present
# 51
# Node  119  already present
# 50
# Adding  323 --> 119
# Node  188  already present
# 43
# Node  315  already present
# 49
# Adding  188 --> 315
# Node  55  already present
# 181
# Node  203  already present
# 107
# Adding  55 --> 203
# Node  137  already present
# 148
# Node  111  already present
# 156
# Adding  137 --> 111
# Node  224  already present
# 114
# Node  200  already present
# 54
# Adding  224 --> 200
# Node  194  already present
# 37
# Node  80  already present
# 133
# Adding  194 --> 80
# Node  295  already present
# 268
# Node  104  already present
# 153
# Adding  295 --> 104
# Node  17  already present
# 131
# Node  140  already present
# 147
# Adding  17 --> 140
# Node  266  already present
# 166
# Node  302  already present
# 100
# Adding  266 --> 302
# Node  232  already present
# 109
# Node  212  already present
# 167
# Adding  232 --> 212
# Node  249  already present
# 177
# Node  24  already present
# 4
# Adding  249 --> 24
# Node  200  already present
# 54
# Node  323  already present
# 51
# Adding  200 --> 323
# Node  323  already present
# 51
# Node  122  already present
# 2
# Adding  323 --> 122
# Node  203  already present
# 107
# Node  65  already present
# 17
# Adding  203 --> 65
# Node  259  already present
# 236
# Inserted node  201
# Adding  259 --> 201
# Node  161  already present
# 135
# Node  56  already present
# 35
# Adding  161 --> 56
# Node  119  already present
# 50
# Node  252  already present
# 14
# Adding  119 --> 252
# Node  238  already present
# 92
# Node  82  already present
# 16
# Adding  238 --> 82
# Node  197  already present
# 73
# Node  251  already present
# 179
# Adding  197 --> 251
# Node  105  already present
# 108
# Node  272  already present
# 21
# Adding  105 --> 272
# Node  291  already present
# 105
# Node  332  already present
# 15
# Adding  291 --> 332
# ...
# Node  312  already present
# 79
# Node  144  already present
# 117
# Adding  312 --> 144
# Node  164  already present
# 312
# Node  285  already present
# 3
# Adding  164 --> 285
# Node  39  already present
# 178
# Node  257  already present
# 186
# Adding  39 --> 257
# Node  132  already present
# 254
# Node  242  already present
# 80
# Adding  132 --> 242
# Node  239  already present
# 27
# Node  40  already present
# 164
# Adding  239 --> 40
# Node  230  already present
# 174
# Node  214  already present
# 81
# Adding  230 --> 214
# Node  80  already present
# 133
# Node  330  already present
# 173
# Adding  80 --> 330
# Node  149  already present
# 128
# Node  14  already present
# 157
# Adding  149 --> 14
# Node  126  already present
# 113
# Node  1  already present
# 125
# Adding  126 --> 1
# Node  21  already present
# 70
# Node  313  already present
# 56
# Adding  21 --> 313
# Node  113  already present
# 184
# Node  199  already present
# 23
# Adding  113 --> 199
# Node  272  already present
# 21
# Node  85  already present
# 143
# Adding  272 --> 85
# Node  257  already present
# 186
# Node  105  already present
# 108
# Adding  257 --> 105
# Node  66  already present
# 136
# Node  134  already present
# 63
# Adding  66 --> 134
# Node  271  already present
# 6
# Node  63  already present
# 57
# Adding  271 --> 63
# Node  274  already present
# 68
# Node  185  already present
# 152
# Adding  274 --> 185
# Node  172  already present
# 28
# Node  203  already present
# 107
# Adding  172 --> 203
# Node  313  already present
# 56
# Node  119  already present
# 50
# Adding  313 --> 119
# Node  119  already present
# 50
# Node  1  already present
# 125
# Adding  119 --> 1
# Node  203  already present
# 107
# Node  341  already present
# 89
# Adding  203 --> 341
# Node  119  already present
# 50
# Node  248  already present
# 112
# Adding  119 --> 248
# Node  8  already present
# 215
# Node  110  already present
# 262
# Adding  8 --> 110
# Node  324  already present
# 154
# Node  27  already present
# 101
# Adding  324 --> 27
# Node  98  already present
# 55
# Node  200  already present
# 54
# Adding  98 --> 200
# Node  323  already present
# 51
# Node  188  already present
# 43
# Adding  323 --> 188
# Node  232  already present
# 109
# Node  271  already present
# 6
# Adding  232 --> 271
# Node  4  already present
# 293
# Node  181  already present
# 214
# Adding  4 --> 181
# Node  21  already present
# 70
# Node  127  already present
# 40
# Adding  21 --> 127
# Node  304  already present
# 7
# Node  285  already present
# 3
# Adding  304 --> 285
# Node  158  already present
# 98
# Node  232  already present
# 109
# Adding  158 --> 232
# Node  211  already present
# 22
# Node  172  already present
# 28
# Adding  211 --> 172
# Node  204  already present
# 12
# Node  180  already present
# 232
# Adding  204 --> 180
# Node  45  already present
# 237
# Node  132  already present
# 254
# Adding  45 --> 132
# Node  98  already present
# 55
# Node  13  already present
# 129
# Adding  98 --> 13
# Node  142  already present
# 106
# Node  203  already present
# 107
# Adding  142 --> 203
# Node  304  already present
# 7
# Node  246  already present
# 144
# Adding  304 --> 246
# Node  269  already present
# 239
# Node  100  already present
# 261
# Adding  269 --> 100
# Node  25  already present
# 120
# Node  65  already present
# 17
# Adding  25 --> 65
# Node  55  already present
# 181
# Node  185  already present
# 152
# Adding  55 --> 185
# Node  213  already present
# 13
# Node  56  already present
# 35
# Adding  213 --> 56
# Node  332  already present
# 15
# Node  213  already present
# 13
# Adding  332 --> 213
# Node  285  already present
# 3
# Node  332  already present
# 15
# Adding  285 --> 332
# Node  142  already present
# 106
# Node  188  already present
# 43
# Adding  142 --> 188
# Node  324  already present
# 154
# Node  224  already present
# 114
# Adding  324 --> 224
# Node  202  already present
# 305
# Node  173  already present
# 227
# Adding  202 --> 173
# Node  48  already present
# 52
# Node  126  already present
# 113
# Adding  48 --> 126
# Node  187  already present
# 134
# Node  266  already present
# 166
# Adding  187 --> 266
# Node  9  already present
# 9
# Node  3  already present
# 31
# Adding  9 --> 3
# Node  113  already present
# 184
# Node  169  already present
# 74
# Adding  113 --> 169
# Node  246  already present
# 144
# Node  285  already present
# 3
# Adding  246 --> 285
# Node  303  already present
# 189
# Node  213  already present
# 13
# Adding  303 --> 213
# Node  142  already present
# 106
# Node  239  already present
# 27
# Adding  142 --> 239
# Node  251  already present
# 179
# Node  184  already present
# 126
# Adding  251 --> 184
# Node  53  already present
# 30
# Node  242  already present
# 80
# Adding  53 --> 242
# Node  172  already present
# 28
# Node  231  already present
# 38
# Adding  172 --> 231
# Node  188  already present
# 43
# Node  13  already present
# 129
# Adding  188 --> 13
# Node  203  already present
# 107
# Node  338  already present
# 202
# Adding  203 --> 338
# Node  111  already present
# 156
# Node  137  already present
# 148
# Adding  111 --> 137
# Node  214  already present
# 81
# Node  19  already present
# 204
# Adding  214 --> 19
# Node  41  already present
# 247
# Node  326  already present
# 132
# Adding  41 --> 326
# Node  113  already present
# 184
# Node  134  already present
# 63
# Adding  113 --> 134
# Node  98  already present
# 55
# Node  304  already present
# 7
# Adding  98 --> 304
# Node  10  already present
# 180
# Node  332  already present
# 15
# Adding  10 --> 332
# Node  184  already present
# 126
# Node  108  already present
# 72
# Adding  184 --> 108
# Node  343  already present
# 149
# Node  20  already present
# 82
# Adding  343 --> 20
# Node  170  already present
# 32
# Node  239  already present
# 27
# Adding  170 --> 239
# Node  147  already present
# 308
# Node  89  already present
# 250
# Adding  147 --> 89
# Node  141  already present
# 94
# Node  25  already present
# 120
# Adding  141 --> 25
# Node  236  already present
# 0
# Node  84  already present
# 24
# Adding  236 --> 84
# Node  34  already present
# 331
# Node  173  already present
# 227
# Adding  34 --> 173
# Node  9  already present
# 9
# Node  231  already present
# 38
# Adding  9 --> 231
# Node  67  already present
# 59
# Node  82  already present
# 16
# Adding  67 --> 82
# Node  148  already present
# 267
# Node  224  already present
# 114
# Adding  148 --> 224
# Node  320  already present
# 142
# Node  197  already present
# 73
# Adding  320 --> 197
# Node  26  already present
# 19
# Node  142  already present
# 106
# Adding  26 --> 142
# Node  241  already present
# 322
# Node  49  already present
# 141
# Adding  241 --> 49
# Node  170  already present
# 32
# Node  119  already present
# 50
# Adding  170 --> 119
# Node  87  already present
# 233
# Node  291  already present
# 105
# Adding  87 --> 291
# Node  199  already present
# 23
# Node  200  already present
# 54
# Adding  199 --> 200
# Node  320  already present
# 142
# Node  80  already present
# 133
# Adding  320 --> 80
# Node  143  already present
# 244
# Node  321  already present
# 273
# Adding  143 --> 321
# Node  217  already present
# 111
# Node  189  already present
# 234
# Adding  217 --> 189
# Node  303  already present
# 189
# Node  67  already present
# 59
# Adding  303 --> 67
# Node  9  already present
# 9
# Node  188  already present
# 43
# Adding  9 --> 188
# Node  122  already present
# 2
# Node  239  already present
# 27
# Adding  122 --> 239
# Node  302  already present
# 100
# Node  299  already present
# 47
# Adding  302 --> 299
# Node  118  already present
# 60
# Node  203  already present
# 107
# Adding  118 --> 203
# Node  62  already present
# 26
# Node  186  already present
# 1
# Adding  62 --> 186
# Node  170  already present
# 32
# Node  62  already present
# 26
# Adding  170 --> 62
# Node  119  already present
# 50
# Node  324  already present
# 154
# Adding  119 --> 324
# Node  137  already present
# 148
# Node  140  already present
# 147
# Adding  137 --> 140
# Node  281  already present
# 198
# Node  135  already present
# 41
# Adding  281 --> 135
# Node  239  already present
# 27
# Node  265  already present
# 93
# Adding  239 --> 265
# Node  200  already present
# 54
# Node  45  already present
# 237
# Adding  200 --> 45
# Node  66  already present
# 136
# Node  122  already present
# 2
# Adding  66 --> 122
# Node  323  already present
# 51
# Node  26  already present
# 19
# Adding  323 --> 26
# Node  203  already present
# 107
# Node  270  already present
# 64
# Adding  203 --> 270
# Node  222  already present
# 161
# Node  211  already present
# 22
# Adding  222 --> 211
# Node  98  already present
# 55
# Node  239  already present
# 27
# Adding  98 --> 239
# Node  239  already present
# 27
# Node  142  already present
# 106
# Adding  239 --> 142
# Node  98  already present
# 55
# Node  109  already present
# 104
# Adding  98 --> 109
# Node  188  already present
# 43
# Node  208  already present
# 253
# Adding  188 --> 208
# Node  67  already present
# 59
# Node  224  already present
# 114
# Adding  67 --> 224
# Node  119  already present
# 50
# Node  318  already present
# 225
# Adding  119 --> 318
# Node  119  already present
# 50
# Node  261  already present
# 115
# Adding  119 --> 261
# Node  59  already present
# 130
# Node  118  already present
# 60
# Adding  59 --> 118
# Node  67  already present
# 59
# Node  122  already present
# 2
# Adding  67 --> 122
# Node  302  already present
# 100
# Node  48  already present
# 52
# Adding  302 --> 48
# Node  206  already present
# 309
# Node  121  already present
# 229
# Adding  206 --> 121
# Node  263  already present
# 199
# Node  68  already present
# 274
# Adding  263 --> 68
# Node  26  already present
# 19
# Node  66  already present
# 136
# Adding  26 --> 66
# Node  236  already present
# 0
# Node  30  already present
# 160
# Adding  236 --> 30
# Node  324  already present
# 154
# Node  67  already present
# 59
# Adding  324 --> 67
# Node  170  already present
# 32
# Node  122  already present
# 2
# Adding  170 --> 122
# Node  88  already present
# 69
# Node  178  already present
# 210
# Adding  88 --> 178
# Node  56  already present
# 35
# Node  113  already present
# 184
# Adding  56 --> 113
# Node  137  already present
# 148
# Node  243  already present
# 212
# Adding  137 --> 243
# Node  25  already present
# 120
# Node  246  already present
# 144
# Adding  25 --> 246
# Node  41  already present
# 247
# Node  20  already present
# 82
# Adding  41 --> 20
# Node  199  already present
# 23
# Node  26  already present
# 19
# Adding  199 --> 26
# Node  254  already present
# 36
# Node  180  already present
# 232
# Adding  254 --> 180
# Node  40  already present
# 164
# Node  258  already present
# 185
# Adding  40 --> 258
# Node  119  already present
# 50
# Node  189  already present
# 234
# Adding  119 --> 189
# Node  304  already present
# 7
# Node  31  already present
# 137
# Adding  304 --> 31
# Node  186  already present
# 1
# Node  25  already present
# 120
# Adding  186 --> 25
# Node  140  already present
# 147
# Node  28  already present
# 78
# Adding  140 --> 28
# Node  98  already present
# 55
# Node  277  already present
# 62
# Adding  98 --> 277
# Node  26  already present
# 19
# Node  56  already present
# 35
# Adding  26 --> 56
# Node  176  already present
# 8
# Node  122  already present
# 2
# Adding  176 --> 122
# Node  317  already present
# 97
# Node  40  already present
# 164
# Adding  317 --> 40
# Node  134  already present
# 63
# Node  277  already present
# 62
# Adding  134 --> 277
# Node  298  already present
# 277
# Node  199  already present
# 23
# Adding  298 --> 199
# Node  281  already present
# 198
# Node  122  already present
# 2
# Adding  281 --> 122
# Node  265  already present
# 93
# Node  252  already present
# 14
# Adding  265 --> 252
# Node  51  already present
# 201
# Node  31  already present
# 137
# Adding  51 --> 31
# Node  285  already present
# 3
# Node  188  already present
# 43
# Adding  285 --> 188
# Node  265  already present
# 93
# Node  26  already present
# 19
# Adding  265 --> 26
# Node  280  already present
# 20
# Node  297  already present
# 151
# Adding  280 --> 297
# Node  63  already present
# 57
# Node  271  already present
# 6
# Adding  63 --> 271
# Node  271  already present
# 6
# Node  314  already present
# 208
# Adding  271 --> 314
# Node  322  already present
# 29
# Node  67  already present
# 59
# Adding  322 --> 67
# Node  297  already present
# 151
# Node  25  already present
# 120
# Adding  297 --> 25
# Node  26  already present
# 19
# Node  248  already present
# 112
# Adding  26 --> 248
# Node  304  already present
# 7
# Node  13  already present
# 129
# Adding  304 --> 13
# Node  181  already present
# 214
# Node  218  already present
# 206
# Adding  181 --> 218
# Node  68  already present
# 274
# Node  296  already present
# 223
# Adding  68 --> 296
# Node  45  already present
# 237
# Node  345  already present
# 96
# Adding  45 --> 345
# Node  89  already present
# 250
# Node  147  already present
# 308
# Adding  89 --> 147
# Node  66  already present
# 136
# Node  308  already present
# 88
# Adding  66 --> 308
# Node  315  already present
# 49
# Node  1  already present
# 125
# Adding  315 --> 1
# Node  185  already present
# 152
# Node  26  already present
# 19
# Adding  185 --> 26
# Node  181  already present
# 214
# Node  306  already present
# 230
# Adding  181 --> 306
# Node  271  already present
# 6
# Node  56  already present
# 35
# Adding  271 --> 56
# Node  105  already present
# 108
# Node  315  already present
# 49
# Adding  105 --> 315
# Node  270  already present
# 64
# Node  25  already present
# 120
# Adding  270 --> 25
# Node  261  already present
# 115
# Node  56  already present
# 35
# Adding  261 --> 56
# Node  158  already present
# 98
# Node  60  already present
# 235
# Adding  158 --> 60
# Node  231  already present
# 38
# Node  25  already present
# 120
# Adding  231 --> 25
# Node  176  already present
# 8
# Node  188  already present
# 43
# Adding  176 --> 188
# Node  246  already present
# 144
# Node  25  already present
# 120
# Adding  246 --> 25
# Node  122  already present
# 2
# Node  136  already present
# 138
# Adding  122 --> 136
# Node  248  already present
# 112
# Node  134  already present
# 63
# Adding  248 --> 134
# Node  331  already present
# 219
# Node  25  already present
# 120
# Adding  331 --> 25
# Node  25  already present
# 120
# Node  332  already present
# 15
# Adding  25 --> 332
# Node  97  already present
# 284
# Node  182  already present
# 320
# Adding  97 --> 182
# Node  201  already present
# 269
# Node  259  already present
# 236
# Adding  201 --> 259
# Node  60  already present
# 235
# Node  313  already present
# 56
# Adding  60 --> 313
# Node  156  already present
# 188
# Node  272  already present
# 21
# Adding  156 --> 272
# Node  268  already present
# 207
# Node  172  already present
# 28
# Adding  268 --> 172
# Node  122  already present
# 2
# Node  251  already present
# 179
# Adding  122 --> 251
# Node  172  already present
# 28
# Node  313  already present
# 56
# Adding  172 --> 313
# Node  342  already present
# 121
# Node  285  already present
# 3
# Adding  342 --> 285
# Node  299  already present
# 47
# Node  1  already present
# 125
# Adding  299 --> 1
# Node  92  already present
# 162
# Node  80  already present
# 133
# Adding  92 --> 80
# Node  343  already present
# 149
# Node  144  already present
# 117
# Adding  343 --> 144
# Node  339  already present
# 71
# Node  158  already present
# 98
# Adding  339 --> 158
# Node  56  already present
# 35
# Node  142  already present
# 106
# Adding  56 --> 142
# Node  109  already present
# 104
# Node  325  already present
# 61
# Adding  109 --> 325
# Node  252  already present
# 14
# Node  170  already present
# 32
# Adding  252 --> 170
# Node  177  already present
# 231
# Node  68  already present
# 274
# Adding  177 --> 68
# Node  265  already present
# 93
# Node  313  already present
# 56
# Adding  265 --> 313
# Node  219  already present
# 315
# Node  154  already present
# 318
# Adding  219 --> 154
# Node  169  already present
# 74
# Node  252  already present
# 14
# Adding  169 --> 252
# Node  24  already present
# 4
# Node  249  already present
# 177
# Adding  24 --> 249
# Node  199  already present
# 23
# Node  313  already present
# 56
# Adding  199 --> 313
# Node  322  already present
# 29
# Node  224  already present
# 114
# Adding  322 --> 224
# Node  128  already present
# 90
# Node  98  already present
# 55
# Adding  128 --> 98
# Node  200  already present
# 54
# Node  142  already present
# 106
# Adding  200 --> 142
# Node  30  already present
# 160
# Node  178  already present
# 210
# Adding  30 --> 178
# Node  13  already present
# 129
# Node  325  already present
# 61
# Adding  13 --> 325
# Node  170  already present
# 32
# Node  252  already present
# 14
# Adding  170 --> 252
# Node  322  already present
# 29
# Node  271  already present
# 6
# Adding  322 --> 271
# Node  88  already present
# 69
# Node  25  already present
# 120
# Adding  88 --> 25
# Node  127  already present
# 40
# Node  197  already present
# 73
# Adding  127 --> 197
# Node  26  already present
# 19
# Node  212  already present
# 167
# Adding  26 --> 212
# Node  62  already present
# 26
# Node  96  already present
# 242
# Adding  62 --> 96
# Node  171  already present
# 155
# Node  58  already present
# 238
# Adding  171 --> 58
# Node  326  already present
# 132
# Node  20  already present
# 82
# Adding  326 --> 20
# Node  85  already present
# 143
# Node  75  already present
# 205
# Adding  85 --> 75
# Node  98  already present
# 55
# Node  332  already present
# 15
# Adding  98 --> 332
# Node  291  already present
# 105
# Node  339  already present
# 71
# Adding  291 --> 339
# 333

# %% [markdown]
# # Centrality Measures

# %%
def calculate_eigen(g):
    eigen=g.evcent(directed=False)
    for i in range(1,7):
        maxVal=max(eigen)
        print(i,'==node',g.vs[eigen.index(maxVal)]['name'],' with score of ',maxVal)
        eigen.remove(maxVal)
    eigen=g.evcent(directed=False)
    return

# %%
def calculate_closeness(g):
    close=g.closeness(g.vs)
    for i in range(1,6):
        maxVal=max(close)
        print(i,'==node',g.vs[close.index(maxVal)]['name'],' with score of ',maxVal)
        close.remove(maxVal)
    close=g.closeness(g.vs)
    return close

# %%
def calculate_between(g):
    between=g.betweenness(g.vs)
    for i in range(1,6):
        maxVal=max(between)
        print(i,'==node',g.vs[between.index(maxVal)]['name'],' with score of ',maxVal)
        between.remove(maxVal)
    between=g.betweenness(g.vs)
    return between

# %%
print('Eigen Vector')
global eigen
eigen=calculate_eigen(g)
# Out:
# Eigen Vector
# 1 ==node 56  with score of  1.0
# 2 ==node 344  with score of  0.9964259456909763
# 3 ==node 271  with score of  0.9774565828157539
# 4 ==node 276  with score of  0.9407290596260329
# 5 ==node 213  with score of  0.8940959611043999
# 6 ==node 122  with score of  0.8327884404144508

# %%
global close
print('Closeness')
close=calculate_closeness(g)
# Out:
# Closeness
# 1 ==node 33  with score of  1.0
# 2 ==node 33  with score of  1.0
# 3 ==node 112  with score of  1.0
# 4 ==node 120  with score of  1.0
# 5 ==node 120  with score of  1.0

# %%
global between
print('Betweenness')
between=calculate_between(g)
# Out:
# Betweenness
# 1 ==node 277  with score of  14607.825084462022
# 2 ==node 175  with score of  13520.81138188322
# 3 ==node 338  with score of  9826.700526023209
# 4 ==node 188  with score of  7155.239878444397
# 5 ==node 144  with score of  4690.348420810955

# %%
load_dataset('sota',g)
# Out:
# 0
# fileName= Dataset/facebook/edges/0.edges
# Node  236  already present
# 0
# Node  186  already present
# 1
# Adding  236 --> 186
# Node  122  already present
# 2
# Node  285  already present
# 3
# Adding  122 --> 285
# Node  24  already present
# 4
# Node  346  already present
# 5
# Adding  24 --> 346
# Node  271  already present
# 6
# Node  304  already present
# 7
# Adding  271 --> 304
# Node  176  already present
# 8
# Node  9  already present
# 9
# Adding  176 --> 9
# Node  130  already present
# 10
# Node  329  already present
# 11
# Adding  130 --> 329
# Node  204  already present
# 12
# Node  213  already present
# 13
# Adding  204 --> 213
# Node  252  already present
# 14
# Node  332  already present
# 15
# Adding  252 --> 332
# Node  82  already present
# 16
# Node  65  already present
# 17
# Adding  82 --> 65
# Node  276  already present
# 18
# Node  26  already present
# 19
# Adding  276 --> 26
# Node  280  already present
# 20
# Node  272  already present
# 21
# Adding  280 --> 272
# Node  211  already present
# 22
# Node  199  already present
# 23
# Adding  211 --> 199
# Node  84  already present
# 24
# Node  236  already present
# 0
# Adding  84 --> 236
# Node  133  already present
# 25
# Node  62  already present
# 26
# Adding  133 --> 62
# Node  239  already present
# 27
# Node  172  already present
# 28
# Adding  239 --> 172
# Node  322  already present
# 29
# Node  53  already present
# 30
# Adding  322 --> 53
# Node  3  already present
# 31
# Node  170  already present
# 32
# Adding  3 --> 170
# Node  175  already present
# 33
# Node  46  already present
# 34
# Adding  175 --> 46
# Node  170  already present
# 32
# Node  176  already present
# 8
# Adding  170 --> 176
# Node  170  already present
# 32
# Node  56  already present
# 35
# Adding  170 --> 56
# Node  254  already present
# 36
# Node  194  already present
# 37
# Adding  254 --> 194
# Node  231  already present
# 38
# Node  117  already present
# 39
# Adding  231 --> 117
# Node  127  already present
# 40
# Node  135  already present
# 41
# Adding  127 --> 135
# Node  285  already present
# 3
# Node  103  already present
# 42
# Adding  285 --> 103
# Node  188  already present
# 43
# Node  133  already present
# 25
# Adding  188 --> 133
# Node  23  already present
# 44
# Node  116  already present
# 45
# Adding  23 --> 116
# Node  73  already present
# 46
# Node  299  already present
# 47
# Adding  73 --> 299
# Node  288  already present
# 48
# Node  315  already present
# 49
# Adding  288 --> 315
# Node  119  already present
# 50
# Node  323  already present
# 51
# Adding  119 --> 323
# Node  48  already present
# 52
# Node  57  already present
# 53
# Adding  48 --> 57
# Node  200  already present
# 54
# Node  98  already present
# 55
# Adding  200 --> 98
# Node  313  already present
# 56
# Node  63  already present
# 57
# Adding  313 --> 63
# Node  199  already present
# 23
# Node  304  already present
# 7
# Adding  199 --> 304
# Node  53  already present
# 30
# Node  346  already present
# 5
# Adding  53 --> 346
# Node  344  already present
# 58
# Node  239  already present
# 27
# Adding  344 --> 239
# Node  56  already present
# 35
# Node  67  already present
# 59
# Adding  56 --> 67
# Node  118  already present
# 60
# Node  325  already present
# 61
# Adding  118 --> 325
# Node  188  already present
# 43
# Node  119  already present
# 50
# Adding  188 --> 119
# Node  26  already present
# 19
# Node  277  already present
# 62
# Adding  26 --> 277
# Node  134  already present
# 63
# Node  56  already present
# 35
# Adding  134 --> 56
# Node  270  already present
# 64
# Node  76  already present
# 65
# Adding  270 --> 76
# Node  135  already present
# 41
# Node  36  already present
# 66
# Adding  135 --> 36
# Node  223  already present
# 67
# Node  170  already present
# 32
# Adding  223 --> 170
# Node  170  already present
# 32
# Node  274  already present
# 68
# Adding  170 --> 274
# Node  88  already present
# 69
# Node  21  already present
# 70
# Adding  88 --> 21
# Node  339  already present
# 71
# Node  119  already present
# 50
# Adding  339 --> 119
# Node  108  already present
# 72
# Node  197  already present
# 73
# Adding  108 --> 197
# Node  169  already present
# 74
# Node  271  already present
# 6
# Adding  169 --> 271
# Node  62  already present
# 26
# Node  236  already present
# 0
# Adding  62 --> 236
# Node  275  already present
# 75
# Node  273  already present
# 76
# Adding  275 --> 273
# Node  88  already present
# 69
# Node  186  already present
# 1
# Adding  88 --> 186
# Node  213  already present
# 13
# Node  186  already present
# 1
# Adding  213 --> 186
# Node  83  already present
# 77
# Node  23  already present
# 44
# Adding  83 --> 23
# Node  28  already present
# 78
# Node  312  already present
# 79
# Adding  28 --> 312
# Node  242  already present
# 80
# Node  57  already present
# 53
# Adding  242 --> 57
# Node  214  already present
# 81
# Node  20  already present
# 82
# Adding  214 --> 20
# Node  307  already present
# 83
# Node  71  already present
# 84
# Adding  307 --> 71
# Node  20  already present
# 82
# Node  333  already present
# 85
# Adding  20 --> 333
# Node  207  already present
# 86
# Node  322  already present
# 29
# Adding  207 --> 322
# Node  339  already present
# 71
# Node  168  already present
# 87
# Adding  339 --> 168
# Node  308  already present
# 88
# Node  277  already present
# 62
# Adding  308 --> 277
# Node  186  already present
# 1
# Node  341  already present
# 89
# Adding  186 --> 341
# Node  322  already present
# 29
# Node  122  already present
# 2
# Adding  322 --> 122
# Node  128  already present
# 90
# Node  9  already present
# 9
# Adding  128 --> 9
# Node  334  already present
# 91
# Node  252  already present
# 14
# Adding  334 --> 252
# Node  238  already present
# 92
# Node  265  already present
# 93
# Adding  238 --> 265
# Node  67  already present
# 59
# Node  141  already present
# 94
# Adding  67 --> 141
# Node  78  already present
# 95
# Node  273  already present
# 76
# Adding  78 --> 273
# Node  345  already present
# 96
# Node  122  already present
# 2
# Adding  345 --> 122
# Node  315  already present
# 49
# Node  345  already present
# 96
# Adding  315 --> 345
# Node  317  already present
# 97
# Node  158  already present
# 98
# Adding  317 --> 158
# Node  98  already present
# 55
# Node  21  already present
# 70
# Adding  98 --> 21
# Node  339  already present
# 71
# Node  38  already present
# 99
# Adding  339 --> 38
# Node  24  already present
# 4
# Node  302  already present
# 100
# Adding  24 --> 302
# Node  27  already present
# 101
# Node  54  already present
# 102
# Adding  27 --> 54
# Node  197  already present
# 73
# Node  139  already present
# 103
# Adding  197 --> 139
# Node  109  already present
# 104
# Node  118  already present
# 60
# Adding  109 --> 118
# Node  252  already present
# 14
# Node  291  already present
# 105
# Adding  252 --> 291
# Node  170  already present
# 32
# Node  142  already present
# 106
# Adding  170 --> 142
# Node  82  already present
# 16
# Node  271  already present
# 6
# Adding  82 --> 271
# Node  203  already present
# 107
# Node  332  already present
# 15
# Adding  203 --> 332
# Node  105  already present
# 108
# Node  9  already present
# 9
# Adding  105 --> 9
# Node  232  already present
# 109
# Node  285  already present
# 3
# Adding  232 --> 285
# Node  64  already present
# 110
# Node  217  already present
# 111
# Adding  64 --> 217
# Node  239  already present
# 27
# Node  62  already present
# 26
# Adding  239 --> 62
# Node  248  already present
# 112
# Node  332  already present
# 15
# Adding  248 --> 332
# Node  73  already present
# 46
# Node  126  already present
# 113
# Adding  73 --> 126
# Node  224  already present
# 114
# Node  261  already present
# 115
# Adding  224 --> 261
# Node  283  already present
# 116
# Node  3  already present
# 31
# Adding  283 --> 3
# Node  144  already present
# 117
# Node  226  already present
# 118
# Adding  144 --> 226
# Node  119  already present
# 50
# Node  48  already present
# 52
# Adding  119 --> 48
# Node  290  already present
# 119
# Node  25  already present
# 120
# Adding  290 --> 25
# Node  172  already present
# 28
# Node  342  already present
# 121
# Adding  172 --> 342
# Node  119  already present
# 50
# Node  170  already present
# 32
# Adding  119 --> 170
# Node  285  already present
# 3
# Node  146  already present
# 122
# Adding  285 --> 146
# Node  300  already present
# 123
# Node  94  already present
# 124
# Adding  300 --> 94
# Node  236  already present
# 0
# Node  142  already present
# 106
# Adding  236 --> 142
# Node  346  already present
# 5
# Node  1  already present
# 125
# Adding  346 --> 1
# Node  184  already present
# 126
# Node  159  already present
# 127
# Adding  184 --> 159
# Node  159  already present
# 127
# Node  139  already present
# 103
# Adding  159 --> 139
# Node  53  already present
# 30
# Node  299  already present
# 47
# Adding  53 --> 299
# Node  149  already present
# 128
# Node  20  already present
# 82
# Adding  149 --> 20
# Node  83  already present
# 77
# Node  25  already present
# 120
# Adding  83 --> 25
# Node  332  already present
# 15
# Node  13  already present
# 129
# Adding  332 --> 13
# Node  25  already present
# 120
# Node  94  already present
# 124
# Adding  25 --> 94
# Node  342  already present
# 121
# Node  59  already present
# 130
# Adding  342 --> 59
# Node  238  already present
# 92
# Node  239  already present
# 27
# Adding  238 --> 239
# Node  17  already present
# 131
# Node  326  already present
# 132
# Adding  17 --> 326
# Node  80  already present
# 133
# Node  187  already present
# 134
# Adding  80 --> 187
# Node  325  already present
# 61
# Node  109  already present
# 104
# Adding  325 --> 109
# Node  224  already present
# 114
# Node  84  already present
# 24
# Adding  224 --> 84
# Node  161  already present
# 135
# Node  142  already present
# 106
# Adding  161 --> 142
# Node  122  already present
# 2
# Node  323  already present
# 51
# Adding  122 --> 323
# Node  161  already present
# 135
# Node  308  already present
# 88
# Adding  161 --> 308
# Node  142  already present
# 106
# Node  66  already present
# 136
# Adding  142 --> 66
# Node  308  already present
# 88
# Node  31  already present
# 137
# Adding  308 --> 31
# Node  136  already present
# 138
# Node  7  already present
# 139
# Adding  136 --> 7
# Node  271  already present
# 6
# Node  252  already present
# 14
# Adding  271 --> 252
# Node  255  already present
# 140
# Node  49  already present
# 141
# Adding  255 --> 49
# Node  48  already present
# 52
# Node  320  already present
# 142
# Adding  48 --> 320
# Node  3  already present
# 31
# Node  85  already present
# 143
# Adding  3 --> 85
# Node  246  already present
# 144
# Node  7  already present
# 139
# Adding  246 --> 7
# Node  109  already present
# 104
# Node  56  already present
# 35
# Adding  109 --> 56
# Node  109  already present
# 104
# Node  119  already present
# 50
# Adding  109 --> 119
# Node  239  already present
# 27
# Node  238  already present
# 92
# Adding  239 --> 238
# Node  272  already present
# 21
# Node  186  already present
# 1
# Adding  272 --> 186
# Node  200  already present
# 54
# Node  123  already present
# 145
# Adding  200 --> 123
# Node  285  already present
# 3
# Node  246  already present
# 144
# Adding  285 --> 246
# Node  271  already present
# 6
# Node  188  already present
# 43
# Adding  271 --> 188
# Node  31  already present
# 137
# Node  277  already present
# 62
# Adding  31 --> 277
# Node  326  already present
# 132
# Node  17  already present
# 131
# Adding  326 --> 17
# Node  284  already present
# 146
# Node  108  already present
# 72
# Adding  284 --> 108
# Node  140  already present
# 147
# Node  137  already present
# 148
# Adding  140 --> 137
# Node  56  already present
# 35
# Node  26  already present
# 19
# Adding  56 --> 26
# Node  343  already present
# 149
# Node  115  already present
# 150
# Adding  343 --> 115
# Node  25  already present
# 120
# Node  323  already present
# 51
# Adding  25 --> 323
# Node  345  already present
# 96
# Node  159  already present
# 127
# Adding  345 --> 159
# Node  297  already present
# 151
# Node  26  already present
# 19
# Adding  297 --> 26
# Node  343  already present
# 149
# Node  149  already present
# 128
# Adding  343 --> 149
# Node  320  already present
# 142
# Node  48  already present
# 52
# Adding  320 --> 48
# Node  200  already present
# 54
# Node  109  already present
# 104
# Adding  200 --> 109
# Node  185  already present
# 152
# Node  271  already present
# 6
# Adding  185 --> 271
# Node  7  already present
# 139
# Node  136  already present
# 138
# Adding  7 --> 136
# Node  326  already present
# 132
# Node  149  already present
# 128
# Adding  326 --> 149
# Node  104  already present
# 153
# Node  56  already present
# 35
# Adding  104 --> 56
# Node  339  already present
# 71
# Node  136  already present
# 138
# Adding  339 --> 136
# Node  308  already present
# 88
# Node  142  already present
# 106
# Adding  308 --> 142
# Node  324  already present
# 154
# Node  329  already present
# 11
# Adding  324 --> 329
# Node  9  already present
# 9
# Node  252  already present
# 14
# Adding  9 --> 252
# Node  1  already present
# 125
# Node  315  already present
# 49
# Adding  1 --> 315
# Node  21  already present
# 70
# Node  274  already present
# 68
# Adding  21 --> 274
# Node  119  already present
# 50
# Node  171  already present
# 155
# Adding  119 --> 171
# Node  345  already present
# 96
# Node  67  already present
# 59
# Adding  345 --> 67
# Node  280  already present
# 20
# Node  1  already present
# 125
# Adding  280 --> 1
# Node  313  already present
# 56
# Node  265  already present
# 93
# Adding  313 --> 265
# Node  277  already present
# 62
# Node  271  already present
# 6
# Adding  277 --> 271
# Node  56  already present
# 35
# Node  88  already present
# 69
# Adding  56 --> 88
# Node  9  already present
# 9
# Node  203  already present
# 107
# Adding  9 --> 203
# Node  85  already present
# 143
# Node  176  already present
# 8
# Adding  85 --> 176
# Node  111  already present
# 156
# Node  343  already present
# 149
# Adding  111 --> 343
# Node  14  already present
# 157
# Node  20  already present
# 82
# Adding  14 --> 20
# Node  310  already present
# 158
# Node  32  already present
# 159
# Adding  310 --> 32
# Node  304  already present
# 7
# Node  30  already present
# 160
# Adding  304 --> 30
# Node  199  already present
# 23
# Node  222  already present
# 161
# Adding  199 --> 222
# Node  92  already present
# 162
# Node  346  already present
# 5
# Adding  92 --> 346
# Node  72  already present
# 163
# Node  40  already present
# 164
# Adding  72 --> 40
# Node  284  already present
# 146
# Node  184  already present
# 126
# Adding  284 --> 184
# Node  125  already present
# 165
# Node  136  already present
# 138
# Adding  125 --> 136
# Node  134  already present
# 63
# Node  118  already present
# 60
# Adding  134 --> 118
# Node  9  already present
# 9
# Node  322  already present
# 29
# Adding  9 --> 322
# Node  302  already present
# 100
# Node  266  already present
# 166
# Adding  302 --> 266
# Node  332  already present
# 15
# Node  104  already present
# 153
# Adding  332 --> 104
# Node  40  already present
# 164
# Node  199  already present
# 23
# Adding  40 --> 199
# Node  212  already present
# 167
# Node  67  already present
# 59
# Adding  212 --> 67
# Node  200  already present
# 54
# Node  277  already present
# 62
# Adding  200 --> 277
# Node  82  already present
# 16
# Node  169  already present
# 74
# Adding  82 --> 169
# Node  270  already present
# 64
# Node  203  already present
# 107
# Adding  270 --> 203
# Node  308  already present
# 88
# Node  172  already present
# 28
# Adding  308 --> 172
# Node  261  already present
# 115
# Node  63  already present
# 57
# Adding  261 --> 63
# Node  146  already present
# 122
# Node  313  already present
# 56
# Adding  146 --> 313
# Node  188  already present
# 43
# Node  285  already present
# 3
# Adding  188 --> 285
# Node  57  already present
# 53
# Node  92  already present
# 162
# Adding  57 --> 92
# Node  168  already present
# 87
# Node  304  already present
# 7
# Adding  168 --> 304
# Node  199  already present
# 23
# Node  265  already present
# 93
# Adding  199 --> 265
# Node  332  already present
# 15
# Node  98  already present
# 55
# Adding  332 --> 98
# Node  169  already present
# 74
# Node  136  already present
# 138
# Adding  169 --> 136
# Node  213  already present
# 13
# Node  57  already present
# 53
# Adding  213 --> 57
# Node  248  already present
# 112
# Node  277  already present
# 62
# Adding  248 --> 277
# Node  98  already present
# 55
# Node  271  already present
# 6
# Adding  98 --> 271
# Node  56  already present
# 35
# Node  141  already present
# 94
# Adding  56 --> 141
# Node  310  already present
# 158
# Node  17  already present
# 131
# Adding  310 --> 17
# Node  199  already present
# 23
# Node  118  already present
# 60
# Adding  199 --> 118
# Node  239  already present
# 27
# Node  141  already present
# 94
# Adding  239 --> 141
# Node  21  already present
# 70
# Node  212  already present
# 167
# Adding  21 --> 212
# Node  176  already present
# 8
# Node  128  already present
# 90
# Adding  176 --> 128
# Node  175  already present
# 33
# Node  278  already present
# 168
# Adding  175 --> 278
# Node  203  already present
# 107
# Node  25  already present
# 120
# Adding  203 --> 25
# Node  265  already present
# 93
# Node  40  already present
# 164
# Adding  265 --> 40
# Node  26  already present
# 19
# Node  252  already present
# 14
# Adding  26 --> 252
# Node  339  already present
# 71
# Node  340  already present
# 169
# Adding  339 --> 340
# Node  172  already present
# 28
# Node  232  already present
# 109
# Adding  172 --> 232
# Node  31  already present
# 137
# Node  237  already present
# 170
# Adding  31 --> 237
# Node  311  already present
# 171
# Node  265  already present
# 93
# Adding  311 --> 265
# Node  309  already present
# 172
# Node  135  already present
# 41
# Adding  309 --> 135
# Node  330  already present
# 173
# Node  80  already present
# 133
# Adding  330 --> 80
# Node  230  already present
# 174
# Node  70  already present
# 175
# Adding  230 --> 70
# Node  272  already present
# 21
# Node  159  already present
# 127
# Adding  272 --> 159
# Node  21  already present
# 70
# Node  134  already present
# 63
# Adding  21 --> 134
# Node  24  already present
# 4
# Node  53  already present
# 30
# Adding  24 --> 53
# Node  40  already present
# 164
# Node  332  already present
# 15
# Adding  40 --> 332
# Node  261  already present
# 115
# Node  16  already present
# 176
# Adding  261 --> 16
# Node  239  already present
# 27
# Node  223  already present
# 67
# Adding  239 --> 223
# Node  304  already present
# 7
# Node  249  already present
# 177
# Adding  304 --> 249
# Node  277  already present
# 62
# Node  39  already present
# 178
# Adding  277 --> 39
# Node  224  already present
# 114
# Node  141  already present
# 94
# Adding  224 --> 141
# Node  142  already present
# 106
# Node  345  already present
# 96
# Adding  142 --> 345
# Node  72  already present
# 163
# Node  141  already present
# 94
# Adding  72 --> 141
# Node  313  already present
# 56
# Node  21  already present
# 70
# Adding  313 --> 21
# Node  261  already present
# 115
# Node  271  already present
# 6
# Adding  261 --> 271
# Node  276  already present
# 18
# Node  25  already present
# 120
# Adding  276 --> 25
# Node  109  already present
# 104
# Node  200  already present
# 54
# Adding  109 --> 200
# Node  288  already present
# 48
# Node  25  already present
# 120
# Adding  288 --> 25
# Node  329  already present
# 11
# Node  291  already present
# 105
# Adding  329 --> 291
# Node  194  already present
# 37
# Node  242  already present
# 80
# Adding  194 --> 242
# Node  223  already present
# 67
# Node  203  already present
# 107
# Adding  223 --> 203
# Node  290  already present
# 119
# Node  170  already present
# 32
# Adding  290 --> 170
# Node  261  already present
# 115
# Node  325  already present
# 61
# Adding  261 --> 325
# Node  36  already present
# 66
# Node  251  already present
# 179
# Adding  36 --> 251
# Node  291  already present
# 105
# Node  10  already present
# 180
# Adding  291 --> 10
# Node  342  already present
# 121
# Node  67  already present
# 59
# Adding  342 --> 67
# Node  21  already present
# 70
# Node  55  already present
# 181
# Adding  21 --> 55
# Node  108  already present
# 72
# Node  284  already present
# 146
# Adding  108 --> 284
# Node  3  already present
# 31
# Node  228  already present
# 182
# Adding  3 --> 228
# Node  168  already present
# 87
# Node  31  already present
# 137
# Adding  168 --> 31
# Node  67  already present
# 59
# Node  69  already present
# 183
# Adding  67 --> 69
# Node  323  already present
# 51
# Node  142  already present
# 106
# Adding  323 --> 142
# Node  261  already present
# 115
# Node  113  already present
# 184
# Adding  261 --> 113
# Node  55  already present
# 181
# Node  200  already present
# 54
# Adding  55 --> 200
# Node  13  already present
# 129
# Node  277  already present
# 62
# Adding  13 --> 277
# Node  322  already present
# 29
# Node  25  already present
# 120
# Adding  322 --> 25
# Node  258  already present
# 185
# Node  257  already present
# 186
# Adding  258 --> 257
# Node  285  already present
# 3
# Node  136  already present
# 138
# Adding  285 --> 136
# Node  80  already present
# 133
# Node  320  already present
# 142
# Adding  80 --> 320
# Node  265  already present
# 93
# Node  98  already present
# 55
# Adding  265 --> 98
# Node  252  already present
# 14
# Node  248  already present
# 112
# Adding  252 --> 248
# Node  62  already present
# 26
# Node  200  already present
# 54
# Adding  62 --> 200
# Node  313  already present
# 56
# Node  54  already present
# 102
# Adding  313 --> 54
# Node  196  already present
# 187
# Node  249  already present
# 177
# Adding  196 --> 249
# Node  323  already present
# 51
# Node  85  already present
# 143
# Adding  323 --> 85
# Node  82  already present
# 16
# Node  231  already present
# 38
# Adding  82 --> 231
# Node  141  already present
# 94
# Node  224  already present
# 114
# Adding  141 --> 224
# Node  342  already present
# 121
# Node  119  already present
# 50
# Adding  342 --> 119
# Node  304  already present
# 7
# Node  325  already present
# 61
# Adding  304 --> 325
# Node  136  already present
# 138
# Node  156  already present
# 188
# Adding  136 --> 156
# Node  325  already present
# 61
# Node  104  already present
# 153
# Adding  325 --> 104
# Node  211  already present
# 22
# Node  325  already present
# 61
# Adding  211 --> 325
# Node  304  already present
# 7
# Node  158  already present
# 98
# Adding  304 --> 158
# Node  254  already present
# 36
# Node  302  already present
# 100
# Adding  254 --> 302
# Node  92  already present
# 162
# Node  242  already present
# 80
# Adding  92 --> 242
# Node  30  already present
# 160
# Node  303  already present
# 189
# Adding  30 --> 303
# Node  274  already present
# 68
# Node  188  already present
# 43
# Adding  274 --> 188
# Node  28  already present
# 78
# Node  310  already present
# 158
# Adding  28 --> 310
# Node  271  already present
# 6
# Node  30  already present
# 160
# Adding  271 --> 30
# Node  286  already present
# 190
# Node  81  already present
# 191
# Adding  286 --> 81
# Node  144  already present
# 117
# Node  326  already present
# 132
# Adding  144 --> 326
# Node  265  already present
# 93
# Node  56  already present
# 35
# Adding  265 --> 56
# Node  249  already present
# 177
# Node  57  already present
# 53
# Adding  249 --> 57
# Node  341  already present
# 89
# Node  186  already present
# 1
# Adding  341 --> 186
# Node  174  already present
# 192
# Node  293  already present
# 193
# Adding  174 --> 293
# Node  33  already present
# 194
# Node  42  already present
# 195
# Adding  33 --> 42
# Node  312  already present
# 79
# Node  28  already present
# 78
# Adding  312 --> 28
# Node  199  already present
# 23
# Node  212  already present
# 167
# Adding  199 --> 212
# Node  9  already present
# 9
# Node  323  already present
# 51
# Adding  9 --> 323
# Node  168  already present
# 87
# Node  347  already present
# 196
# Adding  168 --> 347
# Node  67  already present
# 59
# Node  142  already present
# 106
# Adding  67 --> 142
# Node  1  already present
# 125
# Node  53  already present
# 30
# Adding  1 --> 53
# Node  115  already present
# 150
# Node  2  already present
# 197
# Adding  115 --> 2
# Node  333  already present
# 85
# Node  2  already present
# 197
# Adding  333 --> 2
# Node  332  already present
# 15
# Node  38  already present
# 99
# Adding  332 --> 38
# Node  291  already present
# 105
# Node  280  already present
# 20
# Adding  291 --> 280
# Node  119  already present
# 50
# Node  54  already present
# 102
# Adding  119 --> 54
# Node  271  already present
# 6
# Node  232  already present
# 109
# Adding  271 --> 232
# Node  135  already present
# 41
# Node  281  already present
# 198
# Adding  135 --> 281
# Node  258  already present
# 185
# Node  9  already present
# 9
# Adding  258 --> 9
# Node  285  already present
# 3
# Node  200  already present
# 54
# Adding  285 --> 200
# Node  330  already present
# 173
# Node  94  already present
# 124
# Adding  330 --> 94
# Node  263  already present
# 199
# Node  175  already present
# 33
# Adding  263 --> 175
# Node  212  already present
# 167
# Node  304  already present
# 7
# Adding  212 --> 304
# Node  238  already present
# 92
# Node  342  already present
# 121
# Adding  238 --> 342
# Node  284  already present
# 146
# Node  159  already present
# 127
# Adding  284 --> 159
# Node  111  already present
# 156
# Node  279  already present
# 200
# Adding  111 --> 279
# Node  141  already present
# 94
# Node  172  already present
# 28
# Adding  141 --> 172
# Node  66  already present
# 136
# Node  21  already present
# 70
# Adding  66 --> 21
# Node  313  already present
# 56
# Node  203  already present
# 107
# Adding  313 --> 203
# Node  84  already present
# 24
# Node  51  already present
# 201
# Adding  84 --> 51
# Node  139  already present
# 103
# Node  320  already present
# 142
# Adding  139 --> 320
# Node  25  already present
# 120
# Node  186  already present
# 1
# Adding  25 --> 186
# Node  252  already present
# 14
# Node  338  already present
# 202
# Adding  252 --> 338
# Node  200  already present
# 54
# Node  188  already present
# 43
# Adding  200 --> 188
# Node  59  already present
# 130
# Node  342  already present
# 121
# Adding  59 --> 342
# Node  162  already present
# 203
# Node  149  already present
# 128
# Adding  162 --> 149
# Node  304  already present
# 7
# Node  322  already present
# 29
# Adding  304 --> 322
# Node  185  already present
# 152
# Node  169  already present
# 74
# Adding  185 --> 169
# Node  252  already present
# 14
# Node  236  already present
# 0
# Adding  252 --> 236
# Node  25  already present
# 120
# Node  290  already present
# 119
# Adding  25 --> 290
# Node  56  already present
# 35
# Node  185  already present
# 152
# Adding  56 --> 185
# Node  158  already present
# 98
# Node  40  already present
# 164
# Adding  158 --> 40
# Node  238  already present
# 92
# Node  222  already present
# 161
# Adding  238 --> 222
# Node  56  already present
# 35
# Node  128  already present
# 90
# Adding  56 --> 128
# Node  199  already present
# 23
# Node  261  already present
# 115
# Adding  199 --> 261
# Node  271  already present
# 6
# Node  203  already present
# 107
# Adding  271 --> 203
# Node  63  already present
# 57
# Node  313  already present
# 56
# Adding  63 --> 313
# Node  62  already present
# 26
# Node  161  already present
# 135
# Adding  62 --> 161
# Node  302  already present
# 100
# Node  57  already present
# 53
# Adding  302 --> 57
# Node  19  already present
# 204
# Node  175  already present
# 33
# Adding  19 --> 175
# Node  98  already present
# 55
# Node  172  already present
# 28
# Adding  98 --> 172
# Node  28  already present
# 78
# Node  144  already present
# 117
# Adding  28 --> 144
# Node  249  already present
# 177
# Node  213  already present
# 13
# Adding  249 --> 213
# Node  239  already present
# 27
# Node  252  already present
# 14
# Adding  239 --> 252
# Node  332  already present
# 15
# Node  25  already present
# 120
# Adding  332 --> 25
# Node  265  already present
# 93
# Node  203  already present
# 107
# Adding  265 --> 203
# Node  303  already present
# 189
# Node  104  already present
# 153
# Adding  303 --> 104
# Node  339  already present
# 71
# Node  161  already present
# 135
# Adding  339 --> 161
# Node  119  already present
# 50
# Node  39  already present
# 178
# Adding  119 --> 39
# Node  239  already present
# 27
# Node  211  already present
# 22
# Adding  239 --> 211
# Node  313  already present
# 56
# Node  172  already present
# 28
# Adding  313 --> 172
# Node  200  already present
# 54
# Node  122  already present
# 2
# Adding  200 --> 122
# Node  104  already present
# 153
# Node  303  already present
# 189
# Adding  104 --> 303
# Node  75  already present
# 205
# Node  9  already present
# 9
# Adding  75 --> 9
# Node  137  already present
# 148
# Node  312  already present
# 79
# Adding  137 --> 312
# Node  272  already present
# 21
# Node  203  already present
# 107
# Adding  272 --> 203
# Node  218  already present
# 206
# Node  78  already present
# 95
# Adding  218 --> 78
# Node  261  already present
# 115
# Node  268  already present
# 207
# Adding  261 --> 268
# Node  314  already present
# 208
# Node  65  already present
# 17
# Adding  314 --> 65
# Node  57  already present
# 53
# Node  213  already present
# 13
# Adding  57 --> 213
# Node  21  already present
# 70
# Node  56  already present
# 35
# Adding  21 --> 56
# Node  7  already present
# 139
# Node  213  already present
# 13
# Adding  7 --> 213
# Node  139  already present
# 103
# Node  281  already present
# 198
# Adding  139 --> 281
# Node  5  already present
# 209
# Node  122  already present
# 2
# Adding  5 --> 122
# Node  55  already present
# 181
# Node  21  already present
# 70
# Adding  55 --> 21
# Node  80  already present
# 133
# Node  24  already present
# 4
# Adding  80 --> 24
# Node  178  already present
# 210
# Node  38  already present
# 99
# Adding  178 --> 38
# Node  186  already present
# 1
# Node  109  already present
# 104
# Adding  186 --> 109
# Node  304  already present
# 7
# Node  21  already present
# 70
# Adding  304 --> 21
# Node  192  already present
# 211
# Node  49  already present
# 141
# Adding  192 --> 49
# Node  203  already present
# 107
# Node  21  already present
# 70
# Adding  203 --> 21
# Node  285  already present
# 3
# Node  271  already present
# 6
# Adding  285 --> 271
# Node  122  already present
# 2
# Node  248  already present
# 112
# Adding  122 --> 248
# Node  104  already present
# 153
# Node  322  already present
# 29
# Adding  104 --> 322
# Node  312  already present
# 79
# Node  243  already present
# 212
# Adding  312 --> 243
# Node  302  already present
# 100
# Node  254  already present
# 36
# Adding  302 --> 254
# Node  236  already present
# 0
# Node  169  already present
# 74
# Adding  236 --> 169
# Node  304  already present
# 7
# Node  324  already present
# 154
# Adding  304 --> 324
# Node  266  already present
# 166
# Node  249  already present
# 177
# Adding  266 --> 249
# Node  3  already present
# 31
# Node  280  already present
# 20
# Adding  3 --> 280
# Node  243  already present
# 212
# Node  312  already present
# 79
# Adding  243 --> 312
# Node  211  already present
# 22
# Node  98  already present
# 55
# Adding  211 --> 98
# Node  195  already present
# 213
# Node  181  already present
# 214
# Adding  195 --> 181
# Node  8  already present
# 215
# Node  245  already present
# 216
# Adding  8 --> 245
# Node  297  already present
# 151
# Node  185  already present
# 152
# Adding  297 --> 185
# Node  113  already present
# 184
# Node  104  already present
# 153
# Adding  113 --> 104
# Node  10  already present
# 180
# Node  142  already present
# 106
# Adding  10 --> 142
# Node  129  already present
# 217
# Node  7  already present
# 139
# Adding  129 --> 7
# Node  56  already present
# 35
# Node  297  already present
# 151
# Adding  56 --> 297
# Node  248  already present
# 112
# Node  323  already present
# 51
# Adding  248 --> 323
# Node  273  already present
# 76
# Node  328  already present
# 218
# Adding  273 --> 328
# Node  115  already present
# 150
# Node  19  already present
# 204
# Adding  115 --> 19
# Node  36  already present
# 66
# Node  309  already present
# 172
# Adding  36 --> 309
# Node  129  already present
# 217
# Node  168  already present
# 87
# Adding  129 --> 168
# Node  242  already present
# 80
# Node  194  already present
# 37
# Adding  242 --> 194
# Node  343  already present
# 149
# Node  2  already present
# 197
# Adding  343 --> 2
# Node  21  already present
# 70
# Node  169  already present
# 74
# Adding  21 --> 169
# Node  226  already present
# 118
# Node  343  already present
# 149
# Adding  226 --> 343
# Node  40  already present
# 164
# Node  200  already present
# 54
# Adding  40 --> 200
# Node  172  already present
# 28
# Node  331  already present
# 219
# Adding  172 --> 331
# Node  326  already present
# 132
# Node  343  already present
# 149
# Adding  326 --> 343
# Node  134  already present
# 63
# Node  26  already present
# 19
# Adding  134 --> 26
# Node  332  already present
# 15
# Node  329  already present
# 11
# Adding  332 --> 329
# Node  3  already present
# 31
# Node  200  already present
# 54
# Adding  3 --> 200
# Node  331  already present
# 219
# Node  109  already present
# 104
# Adding  331 --> 109
# Node  150  already present
# 220
# Node  128  already present
# 90
# Adding  150 --> 128
# Node  101  already present
# 221
# Node  299  already present
# 47
# Adding  101 --> 299
# Node  203  already present
# 107
# Node  59  already present
# 130
# Adding  203 --> 59
# Node  231  already present
# 38
# Node  315  already present
# 49
# Adding  231 --> 315
# Node  265  already present
# 93
# Node  199  already present
# 23
# Adding  265 --> 199
# Node  99  already present
# 222
# Node  296  already present
# 223
# Adding  99 --> 296
# Node  322  already present
# 29
# Node  290  already present
# 119
# Adding  322 --> 290
# Node  296  already present
# 223
# Node  102  already present
# 224
# Adding  296 --> 102
# Node  118  already present
# 60
# Node  261  already present
# 115
# Adding  118 --> 261
# Node  238  already present
# 92
# Node  56  already present
# 35
# Adding  238 --> 56
# Node  117  already present
# 39
# Node  231  already present
# 38
# Adding  117 --> 231
# Node  312  already present
# 79
# Node  149  already present
# 128
# Adding  312 --> 149
# Node  304  already present
# 7
# Node  308  already present
# 88
# Adding  304 --> 308
# Node  105  already present
# 108
# Node  277  already present
# 62
# Adding  105 --> 277
# Node  204  already present
# 12
# Node  196  already present
# 187
# Adding  204 --> 196
# Node  315  already present
# 49
# Node  303  already present
# 189
# Adding  315 --> 303
# Node  284  already present
# 146
# Node  21  already present
# 70
# Adding  284 --> 21
# Node  239  already present
# 27
# Node  21  already present
# 70
# Adding  239 --> 21
# Node  312  already present
# 79
# Node  326  already present
# 132
# Adding  312 --> 326
# Node  277  already present
# 62
# Node  161  already present
# 135
# Adding  277 --> 161
# Node  340  already present
# 169
# Node  213  already present
# 13
# Adding  340 --> 213
# Node  98  already present
# 55
# Node  223  already present
# 67
# Adding  98 --> 223
# Node  172  already present
# 28
# Node  277  already present
# 62
# Adding  172 --> 277
# Node  128  already present
# 90
# Node  104  already present
# 153
# Adding  128 --> 104
# Node  313  already present
# 56
# Node  222  already present
# 161
# Adding  313 --> 222
# Node  98  already present
# 55
# Node  331  already present
# 219
# Adding  98 --> 331
# Node  299  already present
# 47
# Node  194  already present
# 37
# Adding  299 --> 194
# Node  122  already present
# 2
# Node  141  already present
# 94
# Adding  122 --> 141
# Node  324  already present
# 154
# Node  217  already present
# 111
# Adding  324 --> 217
# Node  291  already present
# 105
# Node  25  already present
# 120
# Adding  291 --> 25
# Node  13  already present
# 129
# Node  188  already present
# 43
# Adding  13 --> 188
# Node  104  already present
# 153
# Node  318  already present
# 225
# Adding  104 --> 318
# Node  261  already present
# 115
# Node  65  already present
# 17
# Adding  261 --> 65
# Node  265  already present
# 93
# Node  128  already present
# 90
# Adding  265 --> 128
# Node  163  already present
# 226
# Node  173  already present
# 227
# Adding  163 --> 173
# Node  116  already present
# 45
# Node  14  already present
# 157
# Adding  116 --> 14
# Node  92  already present
# 162
# Node  1  already present
# 125
# Adding  92 --> 1
# Node  26  already present
# 19
# Node  3  already present
# 31
# Adding  26 --> 3
# Node  165  already present
# 228
# Node  121  already present
# 229
# Adding  165 --> 121
# Node  3  already present
# 31
# Node  25  already present
# 120
# Adding  3 --> 25
# Node  149  already present
# 128
# Node  226  already present
# 118
# Adding  149 --> 226
# Node  328  already present
# 218
# Node  306  already present
# 230
# Adding  328 --> 306
# Node  172  already present
# 28
# Node  141  already present
# 94
# Adding  172 --> 141
# Node  303  already present
# 189
# Node  315  already present
# 49
# Adding  303 --> 315
# Node  56  already present
# 35
# Node  239  already present
# 27
# Adding  56 --> 239
# Node  122  already present
# 2
# Node  274  already present
# 68
# Adding  122 --> 274
# Node  46  already present
# 34
# Node  177  already present
# 231
# Adding  46 --> 177
# Node  249  already present
# 177
# Node  180  already present
# 232
# Adding  249 --> 180
# Node  73  already present
# 46
# Node  1  already present
# 125
# Adding  73 --> 1
# Node  272  already present
# 21
# Node  346  already present
# 5
# Adding  272 --> 346
# Node  53  already present
# 30
# Node  48  already present
# 52
# Adding  53 --> 48
# Node  199  already present
# 23
# Node  119  already present
# 50
# Adding  199 --> 119
# Node  248  already present
# 112
# Node  38  already present
# 99
# Adding  248 --> 38
# Node  24  already present
# 4
# Node  187  already present
# 134
# Adding  24 --> 187
# Node  196  already present
# 187
# Node  67  already present
# 59
# Adding  196 --> 67
# Node  304  already present
# 7
# Node  172  already present
# 28
# Adding  304 --> 172
# Node  87  already present
# 233
# Node  136  already present
# 138
# Adding  87 --> 136
# Node  323  already present
# 51
# Node  141  already present
# 94
# Adding  323 --> 141
# Node  323  already present
# 51
# Node  62  already present
# 26
# Adding  323 --> 62
# Node  189  already present
# 234
# Node  217  already present
# 111
# Adding  189 --> 217
# Node  280  already present
# 20
# Node  236  already present
# 0
# Adding  280 --> 236
# Node  115  already present
# 150
# Node  137  already present
# 148
# Adding  115 --> 137
# Node  25  already present
# 120
# Node  276  already present
# 18
# Adding  25 --> 276
# Node  186  already present
# 1
# Node  55  already present
# 181
# Adding  186 --> 55
# Node  30  already present
# 160
# Node  56  already present
# 35
# Adding  30 --> 56
# Node  60  already present
# 235
# Node  285  already present
# 3
# Adding  60 --> 285
# Node  197  already present
# 73
# Node  127  already present
# 40
# Adding  197 --> 127
# Node  334  already present
# 91
# Node  26  already present
# 19
# Adding  334 --> 26
# Node  304  already present
# 7
# Node  170  already present
# 32
# Adding  304 --> 170
# Node  259  already present
# 236
# Node  8  already present
# 215
# Adding  259 --> 8
# Node  346  already present
# 5
# Node  184  already present
# 126
# Adding  346 --> 184
# Node  186  already present
# 1
# Node  199  already present
# 23
# Adding  186 --> 199
# Node  200  already present
# 54
# Node  39  already present
# 178
# Adding  200 --> 39
# Node  185  already present
# 152
# Node  344  already present
# 58
# Adding  185 --> 344
# Node  184  already present
# 126
# Node  329  already present
# 11
# Adding  184 --> 329
# Node  149  already present
# 128
# Node  162  already present
# 203
# Adding  149 --> 162
# Node  285  already present
# 3
# Node  213  already present
# 13
# Adding  285 --> 213
# Node  185  already present
# 152
# Node  290  already present
# 119
# Adding  185 --> 290
# Node  13  already present
# 129
# Node  261  already present
# 115
# Adding  13 --> 261
# Node  204  already present
# 12
# Node  5  already present
# 209
# Adding  204 --> 5
# Node  109  already present
# 104
# Node  26  already present
# 19
# Adding  109 --> 26
# Node  169  already present
# 74
# Node  40  already present
# 164
# Adding  169 --> 40
# Node  194  already present
# 37
# Node  196  already present
# 187
# Adding  194 --> 196
# Node  85  already present
# 143
# Node  156  already present
# 188
# Adding  85 --> 156
# Node  67  already present
# 59
# Node  55  already present
# 181
# Adding  67 --> 55
# Node  98  already present
# 55
# Node  285  already present
# 3
# Adding  98 --> 285
# Node  123  already present
# 145
# Node  342  already present
# 121
# Adding  123 --> 342
# Node  118  already present
# 60
# Node  283  already present
# 116
# Adding  118 --> 283
# Node  45  already present
# 237
# Node  67  already present
# 59
# Adding  45 --> 67
# Node  80  already present
# 133
# Node  48  already present
# 52
# Adding  80 --> 48
# Node  162  already present
# 203
# Node  343  already present
# 149
# Adding  162 --> 343
# Node  272  already present
# 21
# Node  21  already present
# 70
# Adding  272 --> 21
# Node  271  already present
# 6
# Node  133  already present
# 25
# Adding  271 --> 133
# Node  67  already present
# 59
# Node  297  already present
# 151
# Adding  67 --> 297
# Node  13  already present
# 129
# Node  118  already present
# 60
# Adding  13 --> 118
# Node  115  already present
# 150
# Node  28  already present
# 78
# Adding  115 --> 28
# Node  230  already present
# 174
# Node  23  already present
# 44
# Adding  230 --> 23
# Node  58  already present
# 238
# Node  269  already present
# 239
# Adding  58 --> 269
# Node  46  already present
# 34
# Node  175  already present
# 33
# Adding  46 --> 175
# Node  25  already present
# 120
# Node  169  already present
# 74
# Adding  25 --> 169
# Node  80  already present
# 133
# Node  57  already present
# 53
# Adding  80 --> 57
# Node  135  already present
# 41
# Node  197  already present
# 73
# Adding  135 --> 197
# Node  203  already present
# 107
# Node  161  already present
# 135
# Adding  203 --> 161
# Node  113  already present
# 184
# Node  261  already present
# 115
# Adding  113 --> 261
# Node  116  already present
# 45
# Node  23  already present
# 44
# Adding  116 --> 23
# Node  275  already present
# 75
# Node  218  already present
# 206
# Adding  275 --> 218
# Node  285  already present
# 3
# Node  170  already present
# 32
# Adding  285 --> 170
# Node  314  already present
# 208
# Node  199  already present
# 23
# Adding  314 --> 199
# Node  279  already present
# 200
# Node  111  already present
# 156
# Adding  279 --> 111
# Node  126  already present
# 113
# Node  48  already present
# 52
# Adding  126 --> 48
# Node  36  already present
# 66
# Node  320  already present
# 142
# Adding  36 --> 320
# Node  137  already present
# 148
# Node  167  already present
# 240
# Adding  137 --> 167
# Node  140  already present
# 147
# Node  326  already present
# 132
# Adding  140 --> 326
# Node  130  already present
# 10
# Node  48  already present
# 52
# Adding  130 --> 48
# Node  302  already present
# 100
# Node  94  already present
# 124
# Adding  302 --> 94
# Node  315  already present
# 49
# Node  80  already present
# 133
# Adding  315 --> 80
# Node  101  already present
# 221
# Node  80  already present
# 133
# Adding  101 --> 80
# Node  23  already present
# 44
# Node  227  already present
# 241
# Adding  23 --> 227
# Node  92  already present
# 162
# Node  194  already present
# 37
# Adding  92 --> 194
# Node  2  already present
# 197
# Node  20  already present
# 82
# Adding  2 --> 20
# Node  72  already present
# 163
# Node  252  already present
# 14
# Adding  72 --> 252
# Node  323  already present
# 51
# Node  96  already present
# 242
# Adding  323 --> 96
# Node  91  already present
# 243
# Node  8  already present
# 215
# Adding  91 --> 8
# Node  143  already present
# 244
# Node  177  already present
# 231
# Adding  143 --> 177
# Node  200  already present
# 54
# Node  30  already present
# 160
# Adding  200 --> 30
# Node  257  already present
# 186
# Node  26  already present
# 19
# Adding  257 --> 26
# Node  331  already present
# 219
# Node  324  already present
# 154
# Adding  331 --> 324
# Node  142  already present
# 106
# Node  322  already present
# 29
# Adding  142 --> 322
# Node  188  already present
# 43
# Node  104  already present
# 153
# Adding  188 --> 104
# Node  239  already present
# 27
# Node  276  already present
# 18
# Adding  239 --> 276
# Node  23  already present
# 44
# Node  61  already present
# 245
# Adding  23 --> 61
# Node  325  already present
# 61
# Node  21  already present
# 70
# Adding  325 --> 21
# Node  204  already present
# 12
# Node  94  already present
# 124
# Adding  204 --> 94
# Node  346  already present
# 5
# Node  194  already present
# 37
# Adding  346 --> 194
# Node  223  already present
# 67
# Node  186  already present
# 1
# Adding  223 --> 186
# Node  56  already present
# 35
# Node  252  already present
# 14
# Adding  56 --> 252
# Node  113  already present
# 184
# Node  142  already present
# 106
# Adding  113 --> 142
# Node  26  already present
# 19
# Node  21  already present
# 70
# Adding  26 --> 21
# Node  285  already present
# 3
# Node  323  already present
# 51
# Adding  285 --> 323
# Node  290  already present
# 119
# Node  176  already present
# 8
# Adding  290 --> 176
# Node  93  already present
# 246
# Node  167  already present
# 240
# Adding  93 --> 167
# Node  276  already present
# 18
# Node  122  already present
# 2
# Adding  276 --> 122
# Node  96  already present
# 242
# Node  133  already present
# 25
# Adding  96 --> 133
# Node  41  already present
# 247
# Node  243  already present
# 212
# Adding  41 --> 243
# Node  188  already present
# 43
# Node  304  already present
# 7
# Adding  188 --> 304
# Node  203  already present
# 107
# Node  313  already present
# 56
# Adding  203 --> 313
# Node  200  already present
# 54
# Node  170  already present
# 32
# Adding  200 --> 170
# Node  232  already present
# 109
# Node  200  already present
# 54
# Adding  232 --> 200
# Node  235  already present
# 248
# Node  5  already present
# 209
# Adding  235 --> 5
# Node  6  already present
# 249
# Node  89  already present
# 250
# Adding  6 --> 89
# Node  171  already present
# 155
# Node  107  already present
# 251
# Adding  171 --> 107
# Node  257  already present
# 186
# Node  169  already present
# 74
# Adding  257 --> 169
# Node  224  already present
# 114
# Node  232  already present
# 109
# Adding  224 --> 232
# Node  271  already present
# 6
# Node  79  already present
# 252
# Adding  271 --> 79
# Node  187  already present
# 134
# Node  24  already present
# 4
# Adding  187 --> 24
# Node  141  already present
# 94
# Node  67  already present
# 59
# Adding  141 --> 67
# Node  113  already present
# 184
# Node  66  already present
# 136
# Adding  113 --> 66
# Node  56  already present
# 35
# Node  103  already present
# 42
# Adding  56 --> 103
# Node  59  already present
# 130
# Node  271  already present
# 6
# Adding  59 --> 271
# Node  40  already present
# 164
# Node  213  already present
# 13
# Adding  40 --> 213
# Node  158  already present
# 98
# Node  26  already present
# 19
# Adding  158 --> 26
# Node  211  already present
# 22
# Node  82  already present
# 16
# Adding  211 --> 82
# Node  285  already present
# 3
# Node  208  already present
# 253
# Adding  285 --> 208
# Node  119  already present
# 50
# Node  285  already present
# 3
# Adding  119 --> 285
# Node  26  already present
# 19
# Node  9  already present
# 9
# Adding  26 --> 9
# Node  40  already present
# 164
# Node  133  already present
# 25
# Adding  40 --> 133
# Node  143  already present
# 244
# Node  175  already present
# 33
# Adding  143 --> 175
# Node  56  already present
# 35
# Node  132  already present
# 254
# Adding  56 --> 132
# Node  45  already present
# 237
# Node  221  already present
# 255
# Adding  45 --> 221
# Node  212  already present
# 167
# Node  344  already present
# 58
# Adding  212 --> 344
# Node  285  already present
# 3
# Node  315  already present
# 49
# Adding  285 --> 315
# Node  301  already present
# 256
# Node  324  already present
# 154
# Adding  301 --> 324
# Node  21  already present
# 70
# Node  170  already present
# 32
# Adding  21 --> 170
# Node  326  already present
# 132
# Node  214  already present
# 81
# Adding  326 --> 214
# Node  281  already present
# 198
# Node  159  already present
# 127
# Adding  281 --> 159
# Node  281  already present
# 198
# Node  251  already present
# 179
# Adding  281 --> 251
# Node  109  already present
# 104
# Node  67  already present
# 59
# Adding  109 --> 67
# Node  25  already present
# 120
# Node  232  already present
# 109
# Adding  25 --> 232
# Node  59  already present
# 130
# Node  56  already present
# 35
# Adding  59 --> 56
# Node  92  already present
# 162
# Node  180  already present
# 232
# Adding  92 --> 180
# Node  122  already present
# 2
# Node  284  already present
# 146
# Adding  122 --> 284
# Node  322  already present
# 29
# Node  48  already present
# 52
# Adding  322 --> 48
# Node  277  already present
# 62
# Node  308  already present
# 88
# Adding  277 --> 308
# Node  290  already present
# 119
# Node  323  already present
# 51
# Adding  290 --> 323
# Node  167  already present
# 240
# Node  93  already present
# 246
# Adding  167 --> 93
# Node  250  already present
# 257
# Node  59  already present
# 130
# Adding  250 --> 59
# Node  106  already present
# 258
# Node  29  already present
# 259
# Adding  106 --> 29
# Node  274  already present
# 68
# Node  341  already present
# 89
# Adding  274 --> 341
# Node  249  already present
# 177
# Node  302  already present
# 100
# Adding  249 --> 302
# Node  118  already present
# 60
# Node  239  already present
# 27
# Adding  118 --> 239
# Node  111  already present
# 156
# Node  337  already present
# 260
# Adding  111 --> 337
# Node  252  already present
# 14
# Node  109  already present
# 104
# Adding  252 --> 109
# Node  56  already present
# 35
# Node  55  already present
# 181
# Adding  56 --> 55
# Node  80  already present
# 133
# Node  266  already present
# 166
# Adding  80 --> 266
# Node  252  already present
# 14
# Node  134  already present
# 63
# Adding  252 --> 134
# Node  104  already present
# 153
# Node  67  already present
# 59
# Adding  104 --> 67
# Node  94  already present
# 124
# Node  346  already present
# 5
# Adding  94 --> 346
# Node  141  already present
# 94
# Node  280  already present
# 20
# Adding  141 --> 280
# Node  325  already present
# 61
# Node  161  already present
# 135
# Adding  325 --> 161
# Node  322  already present
# 29
# Node  203  already present
# 107
# Adding  322 --> 203
# Node  96  already present
# 242
# Node  274  already present
# 68
# Adding  96 --> 274
# Node  158  already present
# 98
# Node  315  already present
# 49
# Adding  158 --> 315
# Node  199  already present
# 23
# Node  98  already present
# 55
# Adding  199 --> 98
# Node  134  already present
# 63
# Node  132  already present
# 254
# Adding  134 --> 132
# Node  280  already present
# 20
# Node  98  already present
# 55
# Adding  280 --> 98
# Node  254  already present
# 36
# Node  187  already present
# 134
# Adding  254 --> 187
# Node  329  already present
# 11
# Node  269  already present
# 239
# Adding  329 --> 269
# Node  297  already present
# 151
# Node  21  already present
# 70
# Adding  297 --> 21
# Node  100  already present
# 261
# Node  150  already present
# 220
# Adding  100 --> 150
# Node  110  already present
# 262
# Node  264  already present
# 263
# Adding  110 --> 264
# Node  266  already present
# 166
# Node  330  already present
# 173
# Adding  266 --> 330
# Node  171  already present
# 155
# Node  150  already present
# 220
# Adding  171 --> 150
# Node  322  already present
# 29
# Node  45  already present
# 237
# Adding  322 --> 45
# Node  72  already present
# 163
# Node  165  already present
# 228
# Adding  72 --> 165
# Node  344  already present
# 58
# Node  257  already present
# 186
# Adding  344 --> 257
# Node  184  already present
# 126
# Node  21  already present
# 70
# Adding  184 --> 21
# Node  119  already present
# 50
# Node  332  already present
# 15
# Adding  119 --> 332
# Node  257  already present
# 186
# Node  236  already present
# 0
# Adding  257 --> 236
# Node  277  already present
# 62
# Node  324  already present
# 154
# Adding  277 --> 324
# Node  332  already present
# 15
# Node  248  already present
# 112
# Adding  332 --> 248
# Node  329  already present
# 11
# Node  119  already present
# 50
# Adding  329 --> 119
# Node  225  already present
# 264
# Node  86  already present
# 265
# Adding  225 --> 86
# Node  232  already present
# 109
# Node  56  already present
# 35
# Adding  232 --> 56
# Node  291  already present
# 105
# Node  224  already present
# 114
# ...
# Node  312  already present
# 79
# Node  144  already present
# 117
# Adding  312 --> 144
# Node  164  already present
# 312
# Node  285  already present
# 3
# Adding  164 --> 285
# Node  39  already present
# 178
# Node  257  already present
# 186
# Adding  39 --> 257
# Node  132  already present
# 254
# Node  242  already present
# 80
# Adding  132 --> 242
# Node  239  already present
# 27
# Node  40  already present
# 164
# Adding  239 --> 40
# Node  230  already present
# 174
# Node  214  already present
# 81
# Adding  230 --> 214
# Node  80  already present
# 133
# Node  330  already present
# 173
# Adding  80 --> 330
# Node  149  already present
# 128
# Node  14  already present
# 157
# Adding  149 --> 14
# Node  126  already present
# 113
# Node  1  already present
# 125
# Adding  126 --> 1
# Node  21  already present
# 70
# Node  313  already present
# 56
# Adding  21 --> 313
# Node  113  already present
# 184
# Node  199  already present
# 23
# Adding  113 --> 199
# Node  272  already present
# 21
# Node  85  already present
# 143
# Adding  272 --> 85
# Node  257  already present
# 186
# Node  105  already present
# 108
# Adding  257 --> 105
# Node  66  already present
# 136
# Node  134  already present
# 63
# Adding  66 --> 134
# Node  271  already present
# 6
# Node  63  already present
# 57
# Adding  271 --> 63
# Node  274  already present
# 68
# Node  185  already present
# 152
# Adding  274 --> 185
# Node  172  already present
# 28
# Node  203  already present
# 107
# Adding  172 --> 203
# Node  313  already present
# 56
# Node  119  already present
# 50
# Adding  313 --> 119
# Node  119  already present
# 50
# Node  1  already present
# 125
# Adding  119 --> 1
# Node  203  already present
# 107
# Node  341  already present
# 89
# Adding  203 --> 341
# Node  119  already present
# 50
# Node  248  already present
# 112
# Adding  119 --> 248
# Node  8  already present
# 215
# Node  110  already present
# 262
# Adding  8 --> 110
# Node  324  already present
# 154
# Node  27  already present
# 101
# Adding  324 --> 27
# Node  98  already present
# 55
# Node  200  already present
# 54
# Adding  98 --> 200
# Node  323  already present
# 51
# Node  188  already present
# 43
# Adding  323 --> 188
# Node  232  already present
# 109
# Node  271  already present
# 6
# Adding  232 --> 271
# Node  4  already present
# 293
# Node  181  already present
# 214
# Adding  4 --> 181
# Node  21  already present
# 70
# Node  127  already present
# 40
# Adding  21 --> 127
# Node  304  already present
# 7
# Node  285  already present
# 3
# Adding  304 --> 285
# Node  158  already present
# 98
# Node  232  already present
# 109
# Adding  158 --> 232
# Node  211  already present
# 22
# Node  172  already present
# 28
# Adding  211 --> 172
# Node  204  already present
# 12
# Node  180  already present
# 232
# Adding  204 --> 180
# Node  45  already present
# 237
# Node  132  already present
# 254
# Adding  45 --> 132
# Node  98  already present
# 55
# Node  13  already present
# 129
# Adding  98 --> 13
# Node  142  already present
# 106
# Node  203  already present
# 107
# Adding  142 --> 203
# Node  304  already present
# 7
# Node  246  already present
# 144
# Adding  304 --> 246
# Node  269  already present
# 239
# Node  100  already present
# 261
# Adding  269 --> 100
# Node  25  already present
# 120
# Node  65  already present
# 17
# Adding  25 --> 65
# Node  55  already present
# 181
# Node  185  already present
# 152
# Adding  55 --> 185
# Node  213  already present
# 13
# Node  56  already present
# 35
# Adding  213 --> 56
# Node  332  already present
# 15
# Node  213  already present
# 13
# Adding  332 --> 213
# Node  285  already present
# 3
# Node  332  already present
# 15
# Adding  285 --> 332
# Node  142  already present
# 106
# Node  188  already present
# 43
# Adding  142 --> 188
# Node  324  already present
# 154
# Node  224  already present
# 114
# Adding  324 --> 224
# Node  202  already present
# 305
# Node  173  already present
# 227
# Adding  202 --> 173
# Node  48  already present
# 52
# Node  126  already present
# 113
# Adding  48 --> 126
# Node  187  already present
# 134
# Node  266  already present
# 166
# Adding  187 --> 266
# Node  9  already present
# 9
# Node  3  already present
# 31
# Adding  9 --> 3
# Node  113  already present
# 184
# Node  169  already present
# 74
# Adding  113 --> 169
# Node  246  already present
# 144
# Node  285  already present
# 3
# Adding  246 --> 285
# Node  303  already present
# 189
# Node  213  already present
# 13
# Adding  303 --> 213
# Node  142  already present
# 106
# Node  239  already present
# 27
# Adding  142 --> 239
# Node  251  already present
# 179
# Node  184  already present
# 126
# Adding  251 --> 184
# Node  53  already present
# 30
# Node  242  already present
# 80
# Adding  53 --> 242
# Node  172  already present
# 28
# Node  231  already present
# 38
# Adding  172 --> 231
# Node  188  already present
# 43
# Node  13  already present
# 129
# Adding  188 --> 13
# Node  203  already present
# 107
# Node  338  already present
# 202
# Adding  203 --> 338
# Node  111  already present
# 156
# Node  137  already present
# 148
# Adding  111 --> 137
# Node  214  already present
# 81
# Node  19  already present
# 204
# Adding  214 --> 19
# Node  41  already present
# 247
# Node  326  already present
# 132
# Adding  41 --> 326
# Node  113  already present
# 184
# Node  134  already present
# 63
# Adding  113 --> 134
# Node  98  already present
# 55
# Node  304  already present
# 7
# Adding  98 --> 304
# Node  10  already present
# 180
# Node  332  already present
# 15
# Adding  10 --> 332
# Node  184  already present
# 126
# Node  108  already present
# 72
# Adding  184 --> 108
# Node  343  already present
# 149
# Node  20  already present
# 82
# Adding  343 --> 20
# Node  170  already present
# 32
# Node  239  already present
# 27
# Adding  170 --> 239
# Node  147  already present
# 308
# Node  89  already present
# 250
# Adding  147 --> 89
# Node  141  already present
# 94
# Node  25  already present
# 120
# Adding  141 --> 25
# Node  236  already present
# 0
# Node  84  already present
# 24
# Adding  236 --> 84
# Node  34  already present
# 331
# Node  173  already present
# 227
# Adding  34 --> 173
# Node  9  already present
# 9
# Node  231  already present
# 38
# Adding  9 --> 231
# Node  67  already present
# 59
# Node  82  already present
# 16
# Adding  67 --> 82
# Node  148  already present
# 267
# Node  224  already present
# 114
# Adding  148 --> 224
# Node  320  already present
# 142
# Node  197  already present
# 73
# Adding  320 --> 197
# Node  26  already present
# 19
# Node  142  already present
# 106
# Adding  26 --> 142
# Node  241  already present
# 322
# Node  49  already present
# 141
# Adding  241 --> 49
# Node  170  already present
# 32
# Node  119  already present
# 50
# Adding  170 --> 119
# Node  87  already present
# 233
# Node  291  already present
# 105
# Adding  87 --> 291
# Node  199  already present
# 23
# Node  200  already present
# 54
# Adding  199 --> 200
# Node  320  already present
# 142
# Node  80  already present
# 133
# Adding  320 --> 80
# Node  143  already present
# 244
# Node  321  already present
# 273
# Adding  143 --> 321
# Node  217  already present
# 111
# Node  189  already present
# 234
# Adding  217 --> 189
# Node  303  already present
# 189
# Node  67  already present
# 59
# Adding  303 --> 67
# Node  9  already present
# 9
# Node  188  already present
# 43
# Adding  9 --> 188
# Node  122  already present
# 2
# Node  239  already present
# 27
# Adding  122 --> 239
# Node  302  already present
# 100
# Node  299  already present
# 47
# Adding  302 --> 299
# Node  118  already present
# 60
# Node  203  already present
# 107
# Adding  118 --> 203
# Node  62  already present
# 26
# Node  186  already present
# 1
# Adding  62 --> 186
# Node  170  already present
# 32
# Node  62  already present
# 26
# Adding  170 --> 62
# Node  119  already present
# 50
# Node  324  already present
# 154
# Adding  119 --> 324
# Node  137  already present
# 148
# Node  140  already present
# 147
# Adding  137 --> 140
# Node  281  already present
# 198
# Node  135  already present
# 41
# Adding  281 --> 135
# Node  239  already present
# 27
# Node  265  already present
# 93
# Adding  239 --> 265
# Node  200  already present
# 54
# Node  45  already present
# 237
# Adding  200 --> 45
# Node  66  already present
# 136
# Node  122  already present
# 2
# Adding  66 --> 122
# Node  323  already present
# 51
# Node  26  already present
# 19
# Adding  323 --> 26
# Node  203  already present
# 107
# Node  270  already present
# 64
# Adding  203 --> 270
# Node  222  already present
# 161
# Node  211  already present
# 22
# Adding  222 --> 211
# Node  98  already present
# 55
# Node  239  already present
# 27
# Adding  98 --> 239
# Node  239  already present
# 27
# Node  142  already present
# 106
# Adding  239 --> 142
# Node  98  already present
# 55
# Node  109  already present
# 104
# Adding  98 --> 109
# Node  188  already present
# 43
# Node  208  already present
# 253
# Adding  188 --> 208
# Node  67  already present
# 59
# Node  224  already present
# 114
# Adding  67 --> 224
# Node  119  already present
# 50
# Node  318  already present
# 225
# Adding  119 --> 318
# Node  119  already present
# 50
# Node  261  already present
# 115
# Adding  119 --> 261
# Node  59  already present
# 130
# Node  118  already present
# 60
# Adding  59 --> 118
# Node  67  already present
# 59
# Node  122  already present
# 2
# Adding  67 --> 122
# Node  302  already present
# 100
# Node  48  already present
# 52
# Adding  302 --> 48
# Node  206  already present
# 309
# Node  121  already present
# 229
# Adding  206 --> 121
# Node  263  already present
# 199
# Node  68  already present
# 274
# Adding  263 --> 68
# Node  26  already present
# 19
# Node  66  already present
# 136
# Adding  26 --> 66
# Node  236  already present
# 0
# Node  30  already present
# 160
# Adding  236 --> 30
# Node  324  already present
# 154
# Node  67  already present
# 59
# Adding  324 --> 67
# Node  170  already present
# 32
# Node  122  already present
# 2
# Adding  170 --> 122
# Node  88  already present
# 69
# Node  178  already present
# 210
# Adding  88 --> 178
# Node  56  already present
# 35
# Node  113  already present
# 184
# Adding  56 --> 113
# Node  137  already present
# 148
# Node  243  already present
# 212
# Adding  137 --> 243
# Node  25  already present
# 120
# Node  246  already present
# 144
# Adding  25 --> 246
# Node  41  already present
# 247
# Node  20  already present
# 82
# Adding  41 --> 20
# Node  199  already present
# 23
# Node  26  already present
# 19
# Adding  199 --> 26
# Node  254  already present
# 36
# Node  180  already present
# 232
# Adding  254 --> 180
# Node  40  already present
# 164
# Node  258  already present
# 185
# Adding  40 --> 258
# Node  119  already present
# 50
# Node  189  already present
# 234
# Adding  119 --> 189
# Node  304  already present
# 7
# Node  31  already present
# 137
# Adding  304 --> 31
# Node  186  already present
# 1
# Node  25  already present
# 120
# Adding  186 --> 25
# Node  140  already present
# 147
# Node  28  already present
# 78
# Adding  140 --> 28
# Node  98  already present
# 55
# Node  277  already present
# 62
# Adding  98 --> 277
# Node  26  already present
# 19
# Node  56  already present
# 35
# Adding  26 --> 56
# Node  176  already present
# 8
# Node  122  already present
# 2
# Adding  176 --> 122
# Node  317  already present
# 97
# Node  40  already present
# 164
# Adding  317 --> 40
# Node  134  already present
# 63
# Node  277  already present
# 62
# Adding  134 --> 277
# Node  298  already present
# 277
# Node  199  already present
# 23
# Adding  298 --> 199
# Node  281  already present
# 198
# Node  122  already present
# 2
# Adding  281 --> 122
# Node  265  already present
# 93
# Node  252  already present
# 14
# Adding  265 --> 252
# Node  51  already present
# 201
# Node  31  already present
# 137
# Adding  51 --> 31
# Node  285  already present
# 3
# Node  188  already present
# 43
# Adding  285 --> 188
# Node  265  already present
# 93
# Node  26  already present
# 19
# Adding  265 --> 26
# Node  280  already present
# 20
# Node  297  already present
# 151
# Adding  280 --> 297
# Node  63  already present
# 57
# Node  271  already present
# 6
# Adding  63 --> 271
# Node  271  already present
# 6
# Node  314  already present
# 208
# Adding  271 --> 314
# Node  322  already present
# 29
# Node  67  already present
# 59
# Adding  322 --> 67
# Node  297  already present
# 151
# Node  25  already present
# 120
# Adding  297 --> 25
# Node  26  already present
# 19
# Node  248  already present
# 112
# Adding  26 --> 248
# Node  304  already present
# 7
# Node  13  already present
# 129
# Adding  304 --> 13
# Node  181  already present
# 214
# Node  218  already present
# 206
# Adding  181 --> 218
# Node  68  already present
# 274
# Node  296  already present
# 223
# Adding  68 --> 296
# Node  45  already present
# 237
# Node  345  already present
# 96
# Adding  45 --> 345
# Node  89  already present
# 250
# Node  147  already present
# 308
# Adding  89 --> 147
# Node  66  already present
# 136
# Node  308  already present
# 88
# Adding  66 --> 308
# Node  315  already present
# 49
# Node  1  already present
# 125
# Adding  315 --> 1
# Node  185  already present
# 152
# Node  26  already present
# 19
# Adding  185 --> 26
# Node  181  already present
# 214
# Node  306  already present
# 230
# Adding  181 --> 306
# Node  271  already present
# 6
# Node  56  already present
# 35
# Adding  271 --> 56
# Node  105  already present
# 108
# Node  315  already present
# 49
# Adding  105 --> 315
# Node  270  already present
# 64
# Node  25  already present
# 120
# Adding  270 --> 25
# Node  261  already present
# 115
# Node  56  already present
# 35
# Adding  261 --> 56
# Node  158  already present
# 98
# Node  60  already present
# 235
# Adding  158 --> 60
# Node  231  already present
# 38
# Node  25  already present
# 120
# Adding  231 --> 25
# Node  176  already present
# 8
# Node  188  already present
# 43
# Adding  176 --> 188
# Node  246  already present
# 144
# Node  25  already present
# 120
# Adding  246 --> 25
# Node  122  already present
# 2
# Node  136  already present
# 138
# Adding  122 --> 136
# Node  248  already present
# 112
# Node  134  already present
# 63
# Adding  248 --> 134
# Node  331  already present
# 219
# Node  25  already present
# 120
# Adding  331 --> 25
# Node  25  already present
# 120
# Node  332  already present
# 15
# Adding  25 --> 332
# Node  97  already present
# 284
# Node  182  already present
# 320
# Adding  97 --> 182
# Node  201  already present
# 269
# Node  259  already present
# 236
# Adding  201 --> 259
# Node  60  already present
# 235
# Node  313  already present
# 56
# Adding  60 --> 313
# Node  156  already present
# 188
# Node  272  already present
# 21
# Adding  156 --> 272
# Node  268  already present
# 207
# Node  172  already present
# 28
# Adding  268 --> 172
# Node  122  already present
# 2
# Node  251  already present
# 179
# Adding  122 --> 251
# Node  172  already present
# 28
# Node  313  already present
# 56
# Adding  172 --> 313
# Node  342  already present
# 121
# Node  285  already present
# 3
# Adding  342 --> 285
# Node  299  already present
# 47
# Node  1  already present
# 125
# Adding  299 --> 1
# Node  92  already present
# 162
# Node  80  already present
# 133
# Adding  92 --> 80
# Node  343  already present
# 149
# Node  144  already present
# 117
# Adding  343 --> 144
# Node  339  already present
# 71
# Node  158  already present
# 98
# Adding  339 --> 158
# Node  56  already present
# 35
# Node  142  already present
# 106
# Adding  56 --> 142
# Node  109  already present
# 104
# Node  325  already present
# 61
# Adding  109 --> 325
# Node  252  already present
# 14
# Node  170  already present
# 32
# Adding  252 --> 170
# Node  177  already present
# 231
# Node  68  already present
# 274
# Adding  177 --> 68
# Node  265  already present
# 93
# Node  313  already present
# 56
# Adding  265 --> 313
# Node  219  already present
# 315
# Node  154  already present
# 318
# Adding  219 --> 154
# Node  169  already present
# 74
# Node  252  already present
# 14
# Adding  169 --> 252
# Node  24  already present
# 4
# Node  249  already present
# 177
# Adding  24 --> 249
# Node  199  already present
# 23
# Node  313  already present
# 56
# Adding  199 --> 313
# Node  322  already present
# 29
# Node  224  already present
# 114
# Adding  322 --> 224
# Node  128  already present
# 90
# Node  98  already present
# 55
# Adding  128 --> 98
# Node  200  already present
# 54
# Node  142  already present
# 106
# Adding  200 --> 142
# Node  30  already present
# 160
# Node  178  already present
# 210
# Adding  30 --> 178
# Node  13  already present
# 129
# Node  325  already present
# 61
# Adding  13 --> 325
# Node  170  already present
# 32
# Node  252  already present
# 14
# Adding  170 --> 252
# Node  322  already present
# 29
# Node  271  already present
# 6
# Adding  322 --> 271
# Node  88  already present
# 69
# Node  25  already present
# 120
# Adding  88 --> 25
# Node  127  already present
# 40
# Node  197  already present
# 73
# Adding  127 --> 197
# Node  26  already present
# 19
# Node  212  already present
# 167
# Adding  26 --> 212
# Node  62  already present
# 26
# Node  96  already present
# 242
# Adding  62 --> 96
# Node  171  already present
# 155
# Node  58  already present
# 238
# Adding  171 --> 58
# Node  326  already present
# 132
# Node  20  already present
# 82
# Adding  326 --> 20
# Node  85  already present
# 143
# Node  75  already present
# 205
# Adding  85 --> 75
# Node  98  already present
# 55
# Node  332  already present
# 15
# Adding  98 --> 332
# Node  291  already present
# 105
# Node  339  already present
# 71
# Adding  291 --> 339

# %%
N=len(g.vs)
layt=g.layout('kk', dim=3)

# %%
labels=[]
#print(type(labels))
for eachNde in g.vs:
    labels.append(eachNde['name'])
#print(labels)

# %%
Edges=list()
print(type(Edges))
for eachTuple in g.es:
    Edges.append(eachTuple.tuple)
print(Edges)
# Out:
# <class 'list'>
# [(0, 1), (0, 2), (0, 6), (0, 7), (0, 13), (0, 14), (0, 18), (0, 19), (0, 20), (0, 21), (0, 24), (0, 25), (0, 26), (0, 29), (0, 49), (0, 54), (0, 59), (0, 69), (0, 70), (0, 74), (0, 94), (0, 106), (0, 108), (0, 112), (0, 114), (0, 120), (0, 125), (0, 129), (0, 151), (0, 160), (0, 183), (0, 186), (0, 189), (0, 208), (0, 225), (0, 229), (1, 2), (1, 3), (1, 6), (1, 9), (1, 13), (1, 14), (1, 19), (1, 21), (1, 23), (1, 26), (1, 27), (1, 29), (1, 32), (1, 35), (1, 43), (1, 51), (1, 54), (1, 55), (1, 59), (1, 61), (1, 62), (1, 67), (1, 69), (1, 70), (1, 89), (1, 90), (1, 96), (1, 104), (1, 106), (1, 107), (1, 120), (1, 130), (1, 145), (1, 153), (1, 161), (1, 181), (1, 184), (1, 189), (1, 210), (1, 219), (1, 237), (1, 255), (2, 3), (2, 6), (2, 7), (2, 8), (2, 9), (2, 13), (2, 14), (2, 15), (2, 18), (2, 19), (2, 20), (2, 21), (2, 26), (2, 27), (2, 29), (2, 31), (2, 32), (2, 35), (2, 43), (2, 49), (2, 50), (2, 51), (2, 54), (2, 55), (2, 58), (2, 59), (2, 61), (2, 62), (2, 68), (2, 70), (2, 74), (2, 90), (2, 94), (2, 96), (2, 104), (2, 106), (2, 107), (2, 109), (2, 112), (2, 114), (2, 115), (2, 120), (2, 121), (2, 135), (2, 136), (2, 137), (2, 138), (2, 145), (2, 146), (2, 151), (2, 153), (2, 179), (2, 181), (2, 184), (2, 188), (2, 189), (2, 198), (2, 209), (2, 237), (2, 248), (3, 6), (3, 7), (3, 9), (3, 13), (3, 14), (3, 15), (3, 19), (3, 21), (3, 22), (3, 27), (3, 29), (3, 32), (3, 35), (3, 39), (3, 42), (3, 43), (3, 49), (3, 50), (3, 51), (3, 54), (3, 55), (3, 56), (3, 59), (3, 62), (3, 96), (3, 104), (3, 106), (3, 107), (3, 109), (3, 115), (3, 120), (3, 121), (3, 122), (3, 138), (3, 144), (3, 152), (3, 180), (3, 184), (3, 187), (3, 189), (3, 235), (3, 253), (3, 255), (3, 312), (4, 5), (4, 30), (4, 37), (4, 47), (4, 53), (4, 80), (4, 100), (4, 124), (4, 133), (4, 134), (4, 162), (4, 166), (4, 177), (4, 221), (4, 232), (5, 10), (5, 12), (5, 21), (5, 30), (5, 36), (5, 37), (5, 40), (5, 47), (5, 53), (5, 80), (5, 100), (5, 123), (5, 124), (5, 125), (5, 126), (5, 133), (5, 134), (5, 142), (5, 162), (5, 166), (5, 173), (5, 177), (5, 187), (5, 221), (5, 232), (6, 7), (6, 8), (6, 9), (6, 14), (6, 15), (6, 16), (6, 18), (6, 19), (6, 20), (6, 21), (6, 22), (6, 23), (6, 25), (6, 27), (6, 28), (6, 29), (6, 32), (6, 35), (6, 42), (6, 43), (6, 49), (6, 50), (6, 51), (6, 52), (6, 54), (6, 55), (6, 56), (6, 57), (6, 59), (6, 60), (6, 61), (6, 62), (6, 67), (6, 70), (6, 74), (6, 90), (6, 92), (6, 93), (6, 94), (6, 104), (6, 105), (6, 106), (6, 107), (6, 109), (6, 114), (6, 115), (6, 119), (6, 120), (6, 121), (6, 129), (6, 130), (6, 135), (6, 143), (6, 151), (6, 152), (6, 153), (6, 160), (6, 163), (6, 164), (6, 167), (6, 184), (6, 207), (6, 208), (6, 219), (6, 225), (6, 252), (6, 267), (6, 277), (7, 9), (7, 14), (7, 15), (7, 19), (7, 20), (7, 21), (7, 22), (7, 23), (7, 24), (7, 27), (7, 28), (7, 29), (7, 32), (7, 35), (7, 43), (7, 49), (7, 54), (7, 55), (7, 59), (7, 60), (7, 61), (7, 62), (7, 63), (7, 70), (7, 87), (7, 88), (7, 89), (7, 91), (7, 94), (7, 98), (7, 104), (7, 107), (7, 114), (7, 129), (7, 135), (7, 136), (7, 137), (7, 138), (7, 139), (7, 144), (7, 154), (7, 160), (7, 164), (7, 167), (7, 177), (7, 183), (7, 184), (7, 186), (7, 196), (7, 205), (8, 9), (8, 19), (8, 27), (8, 32), (8, 43), (8, 50), (8, 90), (8, 119), (8, 120), (8, 143), (8, 267), (9, 11), (9, 14), (9, 18), (9, 19), (9, 20), (9, 21), (9, 23), (9, 25), (9, 29), (9, 31), (9, 32), (9, 35), (9, 38), (9, 43), (9, 49), (9, 50), (9, 51), (9, 54), (9, 59), (9, 62), (9, 63), (9, 70), (9, 74), (9, 89), (9, 90), (9, 91), (9, 94), (9, 105), (9, 106), (9, 107), (9, 108), (9, 109), (9, 114), (9, 120), (9, 121), (9, 135), (9, 136), (9, 143), (9, 151), (9, 152), (9, 160), (9, 163), (9, 183), (9, 184), (9, 185), (9, 188), (9, 205), (9, 252), (9, 267), (9, 268), (10, 11), (10, 12), (10, 13), (10, 26), (10, 29), (10, 30), (10, 46), (10, 52), (10, 62), (10, 69), (10, 120), (10, 123), (10, 186), (10, 307), (11, 12), (11, 15), (11, 20), (11, 21), (11, 28), (11, 29), (11, 38), (11, 49), (11, 50), (11 ...

# %%
Xn=[layt[k][0] for k in range(N)]# x-coordinates of nodes
Yn=[layt[k][1] for k in range(N)]# y-coordinates
Zn=[layt[k][2] for k in range(N)]# z-coordinates
Xe=[]
Ye=[]
Ze=[]

for e in Edges:
    Xe+=[layt[e[0]][0],layt[e[1]][0], None]# x-coordinates of edge ends
    Ye+=[layt[e[0]][1],layt[e[1]][1], None]
    Ze+=[layt[e[0]][2],layt[e[1]][2], None]

# %%
pip install chart_studio
# Out:
# Requirement already satisfied: chart_studio in c:\users\hp\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: requests in c:\users\hp\anaconda3\lib\site-packages (from chart_studio) (2.26.0)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\hp\anaconda3\lib\site-packages (from chart_studio) (1.3.3)
# Requirement already satisfied: plotly in c:\users\hp\anaconda3\lib\site-packages (from chart_studio) (5.7.0)
# Requirement already satisfied: six in c:\users\hp\anaconda3\lib\site-packages (from chart_studio) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\hp\anaconda3\lib\site-packages (from plotly->chart_studio) (8.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests->chart_studio) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from requests->chart_studio) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests->chart_studio) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests->chart_studio) (1.26.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
import chart_studio  
chart_studio.tools.set_credentials_file(username='Vrunda', api_key='xrpevEzzYcUXku9zjLMI')

# %%
import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly.graph_objects import Scatter3d

# %%
Xn[1:20]
# Out:
# [-0.07482938791851923,
#  -0.21974902423264142,
#  0.0372587810988393,
#  0.06632414872509738,
#  0.21911726247815877,
#  0.1426889886363493,
#  0.1035291918581911,
#  0.115037998424843,
#  -0.25018774504591146,
#  -0.055461535789067935,
#  -1.390681140778821,
#  -1.5569595167660875,
#  0.013029755604075752,
#  -0.034271150978281636,
#  -0.1954361479960149,
#  0.3826634642815842,
#  0.9694009879928549,
#  -0.12435628549533678,
#  -0.1612095879248842]

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # Graph at time T

# %%
trace1=go.Scatter3d(x=Xe[1:100],
               y=Ye[1:100],
               z=Ze[1:100],
               mode='lines',
               line=dict(color='rgb(0,0,255)', width=0.6),
               hoverinfo='none'
               )

trace2=go.Scatter3d(x=Xn[1:100],
               y=Yn[1:100],
               z=Zn[1:100],
               mode='markers',
               name='actors',
               marker=dict(symbol='circle',
                             size=6,
                             color=eigen,
                             colorscale='Viridis',
                             line=dict(color='rgb(50,50,5)', width=0.3)
                             ),
               text=labels,
               hoverinfo='text'
               )

axis=dict(showbackground=True,
          showline=False,
          zeroline=False,
          showgrid=False,
          showticklabels=False,
          title=''
          )

layout = go.Layout(
         title="3D Visualization of the Facebook nodes",
         width=1000,
         height=1000,
         showlegend=False,
         scene=dict(
             xaxis=dict(axis),
             yaxis=dict(axis),
             zaxis=dict(axis),
        ),
     margin=dict(
        t=100
    ),
    hovermode='closest',
    annotations=[
           dict(
           showarrow=False,
            text="Data source: <a href='http://bost.ocks.org/mike/miserables/miserables.json'>[1] miserables.json</a>",
            xref='paper',
            yref='paper',
            x=0,
            y=0.1,
            xanchor='left',
            yanchor='bottom',
            font=dict(
            size=14
            )
            )
        ],    )

data=([trace1, trace2])
fig1=go.Figure(data=data, layout=layout)

plt.figure(1)
py.iplot(fig1)



trace1=go.Scatter3d(x=Xe[1:200],
               y=Ye[1:200],
               z=Ze[1:200],
               mode='lines',
               line=dict(color='rgb(0,0,255)', width=0.6),
               hoverinfo='none'
               )

trace2=go.Scatter3d(x=Xn[1:200],
               y=Yn[1:200],
               z=Zn[1:200],
               mode='markers',
               name='actors',
               marker=dict(symbol='circle',
                             size=6,
                             color=eigen,
                             colorscale='Viridis',
                             line=dict(color='rgb(0,250,5)', width=0.3)
                             ),
               text=labels,
               hoverinfo='text'
               )

axis=dict(showbackground=True,
          showline=False,
          zeroline=False,
          showgrid=False,
          showticklabels=False,
          title=''
          )

layout = go.Layout(
         title="3D Visualization of the Facebook nodes",
         width=1000,
         height=1000,
         showlegend=False,
         scene=dict(
             xaxis=dict(axis),
             yaxis=dict(axis),
             zaxis=dict(axis),
        ),
     margin=dict(
        t=100
    ),
    hovermode='closest',
    annotations=[
           dict(
           showarrow=False,
            text="Data source: <a href='http://bost.ocks.org/mike/miserables/miserables.json'>[1] miserables.json</a>",
            xref='paper',
            yref='paper',
            x=0,
            y=0.1,
            xanchor='left',
            yanchor='bottom',
            font=dict(
            size=14
            )
            )
        ],    )

data=([trace1, trace2])
fig2=go.Figure(data=data, layout=layout)
plt.figure(1)
py.iplot(fig2)
# Out:
#         <iframe
#             width="1000px"
#             height="1000px"
#             src="https://plotly.com/~Vrunda/21.embed"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Graph at time T+x

# %%
trace1=go.Scatter3d(x=Xe,
               y=Ye,
               z=Ze,
               mode='lines',
               line=dict(color='rgb(125,125,125)', width=0.6),
               hoverinfo='none'
               )

trace2=go.Scatter3d(x=Xn,
               y=Yn,
               z=Zn,
               mode='markers',
               name='actors',
               marker=dict(symbol='circle',
                             size=6,
                             color=eigen,
                             colorscale='Viridis',
                             line=dict(color='rgb(50,50,5)', width=0.3)
                             ),
               text=labels,
               hoverinfo='text'
               )

axis=dict(showbackground=True,
          showline=False,
          zeroline=False,
          showgrid=False,
          showticklabels=False,
          title=''
          )

layout = go.Layout(
         title="3D Visualization of the Facebook nodes",
         width=1000,
         height=1000,
         showlegend=False,
         scene=dict(
             xaxis=dict(axis),
             yaxis=dict(axis),
             zaxis=dict(axis),
        ),
     margin=dict(
        t=100
    ),
    hovermode='closest',
    annotations=[
           dict(
           showarrow=False,
            text="Data source: <a href='http://bost.ocks.org/mike/miserables/miserables.json'>[1] miserables.json</a>",
            xref='paper',
            yref='paper',
            x=0,
            y=0.1,
            xanchor='left',
            yanchor='bottom',
            font=dict(
            size=14
            )
            )
        ],    )

data=([trace1, trace2])
fig=go.Figure(data=data, layout=layout)

py.iplot(fig)
# Out:
#         <iframe
#             width="1000px"
#             height="1000px"
#             src="https://plotly.com/~Vrunda/23.embed"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
